# %% [markdown]
# <a href="https://colab.research.google.com/github/yongsa-nut/TU_CN240_DataScience_671/blob/main/CN240_Lecture_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lecture 6: Data Wrangling and Data Cleaning

# %% [markdown]
# ## Overview
# - Reshaping data
# - Joining data
# - Examples
# - Dealing with Text
# - Missing data (if we have time today.)

# %% [markdown]
# ## Reshaping Data

# %% [markdown]
# ### `melt()`
# - `melt()` turn a wide table into a long table.
# - The format that we want is row = one observation, column = one variable.
# - Syntax: `melt(id_vars, value_vars)`
#   - `id_vars`: specifies the column(s) that should **remain unchanged**
#   - `value_vars`: Column(s) to be a new column.
#
# <img src= 'https://drive.google.com/thumbnail?id=1JK2hmw6XcfajDNgQgryKLMqXoVm9QF2o&sz=w1000'></img>

# %%
import pandas as pd

# %%
# load the data
# Get the data from github
wide_data = pd.read_csv('/content/fertility-two-countries-example.csv')
wide_data
# Out:
#        country  1960  1961  1962  1963  1964  1965  1966  1967  1968  ...  \
# 0      Germany  2.41  2.44  2.47  2.49  2.49  2.48  2.44  2.37  2.28  ...
# 1  South Korea  6.16  5.99  5.79  5.57  5.36  5.16  4.99  4.85  4.73  ...
#
#    2006  2007  2008  2009  2010  2011  2012  2013  2014  2015
# 0  1.36  1.36  1.37  1.38  1.39  1.40  1.41  1.42  1.43  1.44
# 1  1.20  1.21  1.23  1.25  1.27  1.29  1.30  1.32  1.34  1.36
#
# [2 rows x 57 columns]

# %%
new_data = wide_data.melt(id_vars = ['country'],
                          value_vars = wide_data.columns[1:],
                          var_name= 'year',
                          value_name='fertility'
                          )
new_data
# Out:
#          country  year  fertility
# 0        Germany  1960       2.41
# 1    South Korea  1960       6.16
# 2        Germany  1961       2.44
# 3    South Korea  1961       5.99
# 4        Germany  1962       2.47
# ..           ...   ...        ...
# 107  South Korea  2013       1.32
# 108      Germany  2014       1.43
# 109  South Korea  2014       1.34
# 110      Germany  2015       1.44
# 111  South Korea  2015       1.36
#
# [112 rows x 3 columns]

# %% [markdown]
# ### `pivot`
#
# - We can convert from long data to wide data using `pivot`
# - Syntax: `df.pivot(index=ids, columns='var', values='val)`
#   - The `index` parameter specifies the columns that should **remain as index** columns.
#   -  The `columns` parameter specifies the column that will be used to **create new columns**.
#   - The `values` parameter specifies the column that contains the **values to be filled** in the new columns.
#
# <img src= 'https://drive.google.com/thumbnail?id=1H-FhwpQ2zBOcdGEgOZ5EQEd9dHb4Ua75&sz=w1000'></img>

# %%
new_wide_data = new_data.pivot(index=['country'],
                               columns = ['year'],
                               values =['fertility'])

# Flatten the MultiIndex in columns
new_wide_data.columns = new_wide_data.columns.get_level_values(1)

# Reset the index to make 'country' a regular column
new_wide_data = new_wide_data.reset_index()

new_wide_data
# Out:
# year      country  1960  1961  1962  1963  1964  1965  1966  1967  1968  ...  \
# 0         Germany  2.41  2.44  2.47  2.49  2.49  2.48  2.44  2.37  2.28  ...
# 1     South Korea  6.16  5.99  5.79  5.57  5.36  5.16  4.99  4.85  4.73  ...
#
# year  2006  2007  2008  2009  2010  2011  2012  2013  2014  2015
# 0     1.36  1.36  1.37  1.38  1.39  1.40  1.41  1.42  1.43  1.44
# 1     1.20  1.21  1.23  1.25  1.27  1.29  1.30  1.32  1.34  1.36
#
# [2 rows x 57 columns]

# %% [markdown]
# #### Separating Variables

# %%
combined_data = pd.read_csv('/content/life-expectancy-and-fertility-two-countries-example.csv')
combined_data
# Out:
#        country  1960_fertility  1960_life_expectancy  1961_fertility  \
# 0      Germany            2.41                 69.26            2.44
# 1  South Korea            6.16                 53.02            5.99
#
#    1961_life_expectancy  1962_fertility  1962_life_expectancy  1963_fertility  \
# 0                 69.85            2.47                 70.01            2.49
# 1                 53.75            5.79                 54.51            5.57
#
#    1963_life_expectancy  1964_fertility  ...  2011_fertility  \
# 0                 70.10            2.49  ...            1.40
# 1                 55.27            5.36  ...            1.29
#
#    2011_life_expectancy  2012_fertility  2012_life_expectancy  2013_fertility  \
# 0                  80.5            1.41                  80.6            1.42
# 1                  80.6            1.30                  80.7            1.32
#
#    2013_life_expectancy  2014_fertility  2014_life_expectancy  2015_fertility  \
# 0                  80.7            1.43                  80.7            1.44
# 1                  80.9            1.34                  80.9            1.36
#
#    2015_life_expectancy
# 0                  80.8
# 1                  81.0
#
# [2 rows x 113 columns]

# %% [markdown]
# - We want to create a long table with four columns:
#   - country
#   - year
#   - fertility
#   - life_expectancy
# - Steps:
#   1. melt
#   2. Create two new columns using str.split()
#   3. pivot with country and value

# %%
# 1. Melt
## We can skip value_vars, since we use the rest of columns
df_long = combined_data.melt(id_vars=['country'],
                  var_name='temp',
                  value_name='value')
df_long
# Out:
#          country                  temp  value
# 0        Germany        1960_fertility   2.41
# 1    South Korea        1960_fertility   6.16
# 2        Germany  1960_life_expectancy  69.26
# 3    South Korea  1960_life_expectancy  53.02
# 4        Germany        1961_fertility   2.44
# ..           ...                   ...    ...
# 219  South Korea  2014_life_expectancy  80.90
# 220      Germany        2015_fertility   1.44
# 221  South Korea        2015_fertility   1.36
# 222      Germany  2015_life_expectancy  80.80
# 223  South Korea  2015_life_expectancy  81.00
#
# [224 rows x 3 columns]

# %%
# 2. Create two new columns based on str.split()
df_long[['year', 'variable']] = df_long['temp'].str.split('_', n=1, expand=True)
df_long
# Out:
#          country                  temp  value  year         variable
# 0        Germany        1960_fertility   2.41  1960        fertility
# 1    South Korea        1960_fertility   6.16  1960        fertility
# 2        Germany  1960_life_expectancy  69.26  1960  life_expectancy
# 3    South Korea  1960_life_expectancy  53.02  1960  life_expectancy
# 4        Germany        1961_fertility   2.44  1961        fertility
# ..           ...                   ...    ...   ...              ...
# 219  South Korea  2014_life_expectancy  80.90  2014  life_expectancy
# 220      Germany        2015_fertility   1.44  2015        fertility
# 221  South Korea        2015_fertility   1.36  2015        fertility
# 222      Germany  2015_life_expectancy  80.80  2015  life_expectancy
# 223  South Korea  2015_life_expectancy  81.00  2015  life_expectancy
#
# [224 rows x 5 columns]

# %%
df_long = df_long.pivot(index=['country', 'year'],
                        columns='variable',
                        values='value').reset_index()
df_long
# Out:
# variable      country  year  fertility  life_expectancy
# 0             Germany  1960       2.41            69.26
# 1             Germany  1961       2.44            69.85
# 2             Germany  1962       2.47            70.01
# 3             Germany  1963       2.49            70.10
# 4             Germany  1964       2.49            70.66
# ..                ...   ...        ...              ...
# 107       South Korea  2011       1.29            80.60
# 108       South Korea  2012       1.30            80.70
# 109       South Korea  2013       1.32            80.90
# 110       South Korea  2014       1.34            80.90
# 111       South Korea  2015       1.36            81.00
#
# [112 rows x 4 columns]

# %% [markdown]
# ## Joining Tables
#
# - Sometimes, we need to combine a few data together.
# - Pandas provide a function `merge` to join two data in various ways.
#
# <img src= 'https://drive.google.com/thumbnail?id=1eCljI-KPaOhAAHow6Yj4qKfqu1mOhRIn&sz=w1000'></img>

# %% [markdown]
# #### joining example

# %%
# load the data
murders = pd.read_csv('/content/murders.csv')
election2016 = pd.read_csv('/content/results_us_election_2016.csv')

# %%
murders.head()
# Out:
#         state abb region  population  total
# 0     Alabama  AL  South     4779736    135
# 1      Alaska  AK   West      710231     19
# 2     Arizona  AZ   West     6392017    232
# 3    Arkansas  AR  South     2915918     93
# 4  California  CA   West    37253956   1257

# %%
election2016.head()
# Out:
#    Unnamed: 0       state  electoral_votes  clinton  trump  others
# 0           1  California               55     61.7   31.6     6.7
# 1           2       Texas               38     43.2   52.2     4.5
# 2           3     Florida               29     47.8   49.0     3.2
# 3           4    New York               29     59.0   36.5     4.5
# 4           5    Illinois               20     55.8   38.8     5.4

# %%
# Merge by state
first_merge =  pd.merge(murders, election2016, on='state', how='left')
first_merge
# Out:
#                    state abb         region  population  total  Unnamed: 0  \
# 0                Alabama  AL          South     4779736    135          22
# 1                 Alaska  AK           West      710231     19          44
# 2                Arizona  AZ           West     6392017    232          14
# 3               Arkansas  AR          South     2915918     93          30
# 4             California  CA           West    37253956   1257           1
# 5               Colorado  CO           West     5029196     65          23
# 6            Connecticut  CT      Northeast     3574097     97          27
# 7               Delaware  DE          South      897934     38          45
# 8   District of Columbia  DC          South      601723     99          51
# 9                Florida  FL          South    19687653    669           3
# 10               Georgia  GA          South     9920000    376           8
# 11                Hawaii  HI           West     1360301      7          39
# 12                 Idaho  ID           West     1567582     12          40
# 13              Illinois  IL  North Central    12830632    364           5
# 14               Indiana  IN  North Central     6483802    142          15
# 15                  Iowa  IA  North Central     3046355     21          31
# 16                Kansas  KS  North Central     2853118     63          32
# 17              Kentucky  KY          South     4339367    116          25
# 18             Louisiana  LA          South     4533372    351          26
# 19                 Maine  ME      Northeast     1328361     11          41
# 20              Maryland  MD          South     5773552    293          18
# 21         Massachusetts  MA      Northeast     6547629    118          16
# 22              Michigan  MI  North Central     9883640    413           9
# 23             Minnesota  MN  North Central     5303925     53          19
# 24           Mississippi  MS          South     2967297    120          33
# 25              Missouri  MO  North Central     5988927    321          20
# 26               Montana  MT           West      989415     12          46
# 27              Nebraska  NE  North Central     1826341     32          36
# 28                Nevada  NV           West     2700551     84          34
# 29         New Hampshire  NH      Northeast     1316470      5          42
# 30            New Jersey  NJ      Northeast     8791894    246          11
# 31            New Mexico  NM           West     2059179     67          37
# 32              New York  NY      Northeast    19378102    517           4
# 33        North Carolina  NC          South     9535483    286          10
# 34          North Dakota  ND  North Central      672591      4          47
# 35                  Ohio  OH  North Central    11536504    310           7
# 36              Oklahoma  OK          South     3751351    111          28
# 37                Oregon  OR           West     3831074     36          29
# 38          Pennsylvania  PA      Northeast    12702379    457           6
# 39          Rhode Island  RI      Northeast     1052567     16          43
# 40        South Carolina  SC          South     4625364    207          24
# 41          South Dakota  SD  North Central      814180      8          48
# 42             Tennessee  TN          South     6346105    219          17
# 43                 Texas  TX          South    25145561    805           2
# 44                  Utah  UT           West     2763885     22          35
# 45               Vermont  VT      Northeast      625741      2          49
# 46              Virginia  VA          South     8001024    250          12
# 47            Washington  WA           West     6724540     93          13
# 48         West Virginia  WV          South     1852994     27          38
# 49             Wisconsin  WI  North Central     5686986     97          21
# 50               Wyoming  WY           West      563626      5          50
#
#     electoral_votes  clinton  trump  others
# 0                 9     34.4   62.1     3.6
# 1                 3     36.6   51.3    12.2
# 2                11     45.1   48.7     6.2
# 3                 6     33.7   60.6     5.8
# 4                55     61.7   31.6     6.7
# 5                 9     48.2   43.3     8.6
# 6                 7     54.6   40.9     4.5
# 7                 3     53.4   41.9     4.7
# 8                 3     90.9    4.1     5.0
# 9                29     47.8   49.0     3.2
# 10               16     45.9   51.0     3.1
# 11                4     62.2   30.0     7.7
# 12                4     27.5   59.3    13.2
# 13               20     55.8   38.8     5.4
# 14               11     37.8   56.9     5.3
# 15                6     41.7   51.1     7.1
# 16                6     36.1   56.7     7.3
# 17                8     32.7   62.5     4.8
# 18                8     38.4   58.1     3.5
# 19                4     48.0   45.0     7.0
# 20               10     60.3   33.9     5.8
# 21               11     60.0   32.8     7.2
# 22               16     47.3   47.5     5.2
# 23               10     46.4   44.9     8.6
# 24                6     40.1   57.9     1.9
# 25               10     38.1   56.8     5.1
# 26                3     35.9   56.5     7.6
# 27                5     34.3   59.9     5.8
# 28                6     47.9   45.5     6.6
# 29                4     46.8   46.5     6.7
# 30               14     55.5   41.4     3.2
# 31                5     48.3   40.0    11.7
# 32               29     59.0   36.5     4.5
# 33               15     46.2   49.8     4.0
# 34                3     27.2   63.0     9.8
# 35               18     43.5   51.7     4.8
# 36                7     28.9   65.3     5.7
# 37                7     50.1   39.1    10.8
# 38               20     47.9   48.6     3.6
# 39                4     54.4   38.9     6.7
# 40                9     40.7   54.9     4.4
# 41                3     31.7   61.5     6.7
# 42               11     34.7   60.7     4.6
# 43               38     43.2   52.2     4.5
# 44                6     27.5   45.5    27.0
# 45                3     56.7   30.3    13.1
# 46               13     49.8   44.4     5.8
# 47               12     54.3   38.1     7.6
# 48                5     26.5   68.6     4.9
# 49               10     46.5   47.2     6.3
# 50                3     21.9   68.2    10.0

# %% [markdown]
# #### Joining Example 2
#
# - We will be looking at Tuberculosis in the United States.
# - We can download this data from CDC https://www.cdc.gov/mmwr/volumes/71/wr/mm7112a1.htm?s_cid=mm7112a1_w#T1_down

# %%
# More about this next week
#tbls = pd.read_html("https://www.cdc.gov/mmwr/volumes/71/wr/mm7112a1.htm?s_cid=mm7112a1_w#T1_down")
#df = tbls[0] # First table on the website
#df.to_csv('cdc_tuberculosis.csv')

# %%
tb_df = pd.read_csv("/content/cdc_tuberculosis.csv",)
tb_df
# Out:
#     Unnamed: 0     U.S. jurisdiction  No. of TB cases*  No. of TB cases*.1  \
# 0          NaN     U.S. jurisdiction              2019                2020
# 1          0.0                 Total              8900                7173
# 2          1.0               Alabama                87                  72
# 3          2.0                Alaska                58                  58
# 4          3.0               Arizona               183                 136
# 5          4.0              Arkansas                64                  59
# 6          5.0            California              2111                1706
# 7          6.0              Colorado                66                  52
# 8          7.0           Connecticut                67                  54
# 9          8.0              Delaware                18                  17
# 10         9.0  District of Columbia                24                  19
# 11        10.0               Florida               558                 412
# 12        11.0               Georgia               302                 221
# 13        12.0                Hawaii                99                  92
# 14        13.0                 Idaho                 7                   8
# 15        14.0              Illinois               326                 216
# 16        15.0               Indiana               108                  92
# 17        16.0                  Iowa                52                  39
# 18        17.0                Kansas                37                  37
# 19        18.0              Kentucky                66                  67
# 20        19.0             Louisiana                88                  99
# 21        20.0                 Maine                18                  17
# 22        21.0              Maryland               209                 148
# 23        22.0         Massachusetts               178                 142
# 24        23.0              Michigan               131                 101
# 25        24.0             Minnesota               148                 117
# 26        25.0           Mississippi                58                  41
# 27        26.0              Missouri                70                  79
# 28        27.0               Montana                 2                   4
# 29        28.0              Nebraska                17                  33
# 30        29.0                Nevada                53                  57
# 31        30.0         New Hampshire                 6                  12
# 32        31.0            New Jersey               310                 245
# 33        32.0            New Mexico                41                  29
# 34        33.0              New York               746                 605
# 35        34.0        North Carolina               185                 159
# 36        35.0          North Dakota                18                  10
# 37        36.0                  Ohio               150                 130
# 38        37.0              Oklahoma                73                  67
# 39        38.0                Oregon                70                  67
# 40        39.0          Pennsylvania               199                 156
# 41        40.0          Rhode Island                14                   7
# 42        41.0        South Carolina                80                  67
# 43        42.0          South Dakota                16                  16
# 44        43.0             Tennessee               129                 113
# 45        44.0                 Texas              1154                 883
# 46        45.0                  Utah                27                  29
# 47        46.0               Vermont                 4                   3
# 48        47.0              Virginia               191                 169
# 49        48.0            Washington               221                 163
# 50        49.0         West Virginia                 9                  13
# 51        50.0             Wisconsin                51                  35
# 52        51.0               Wyoming                 1                   0
#
#     No. of TB cases*.2  TB incidence†  TB incidence†.1  TB incidence†.2
# 0                 2021        2019.00          2020.00          2021.00
# 1                 7860           2.71             2.16             2.37
# 2                   92           1.77             1.43             1.83
# 3                   58           7.91             7.92             7.92
# 4                  129           2.51             1.89             1.77
# 5                   69           2.12             1.96             2.28
# 6                 1750           5.35             4.32             4.46
# 7                   58           1.15             0.90             1.00
# 8                   54           1.88             1.50             1.50
# 9                   43           1.84             1.71             4.29
# 10                  19           3.39             2.75             2.84
# 11                 499           2.60             1.91             2.29
# 12                 228           2.84             2.06             2.11
# 13                 106           6.99             6.34             7.35
# 14                   4           0.39             0.43             0.21
# 15                 255           2.57             1.69             2.01
# 16                 127           1.60             1.36             1.87
# 17                  49           1.65             1.22             1.53
# 18                  43           1.27             1.26             1.47
# 19                  57           1.48             1.49             1.26
# 20                  86           1.89             2.13             1.86
# 21                  14           1.34             1.25             1.02
# 22                 192           3.45             2.40             3.11
# 23                 151           2.58             2.02             2.16
# 24                 136           1.31             1.00             1.35
# 25                 134           2.62             2.05             2.35
# 26                  45           1.95             1.39             1.53
# 27                  77           1.14             1.28             1.25
# 28                   3           0.19             0.37             0.27
# 29                  22           0.88             1.68             1.12
# 30                  61           1.71             1.83             1.94
# 31                  12           0.44             0.87             0.86
# 32                 279           3.49             2.64             3.01
# 33                  24           1.95             1.37             1.13
# 34                 681           3.83             3.00             3.43
# 35                 178           1.76             1.52             1.69
# 36                  15           2.36             1.28             1.94
# 37                 149           1.28             1.10             1.26
# 38                  69           1.84             1.69             1.73
# 39                  78           1.66             1.58             1.84
# 40                 166           1.55             1.20             1.28
# 41                  17           1.32             0.64             1.55
# 42                  88           1.55             1.31             1.70
# 43                  12           1.80             1.80             1.34
# 44                  85           1.89             1.63             1.22
# 45                 991           3.98             3.02             3.36
# 46                  17           0.84             0.88             0.51
# 47                   2           0.64             0.47             0.31
# 48                 161           2.23             1.96             1.86
# 49                 199           2.90             2.11             2.57
# 50                   7           0.50             0.73             0.39
# 51                  66           0.88             0.59             1.12
# 52                   3           0.17             0.00             0.52

# %% [markdown]
# - The first row should be the column names/headers
# - Always check your header

# %%
tb_df = pd.read_csv("/content/cdc_tuberculosis.csv", header=1) # row index
tb_df = tb_df.drop(columns=tb_df.columns[0])
tb_df
# Out:
#        U.S. jurisdiction  2019  2020  2021  2019.1  2020.1  2021.1
# 0                  Total  8900  7173  7860    2.71    2.16    2.37
# 1                Alabama    87    72    92    1.77    1.43    1.83
# 2                 Alaska    58    58    58    7.91    7.92    7.92
# 3                Arizona   183   136   129    2.51    1.89    1.77
# 4               Arkansas    64    59    69    2.12    1.96    2.28
# 5             California  2111  1706  1750    5.35    4.32    4.46
# 6               Colorado    66    52    58    1.15    0.90    1.00
# 7            Connecticut    67    54    54    1.88    1.50    1.50
# 8               Delaware    18    17    43    1.84    1.71    4.29
# 9   District of Columbia    24    19    19    3.39    2.75    2.84
# 10               Florida   558   412   499    2.60    1.91    2.29
# 11               Georgia   302   221   228    2.84    2.06    2.11
# 12                Hawaii    99    92   106    6.99    6.34    7.35
# 13                 Idaho     7     8     4    0.39    0.43    0.21
# 14              Illinois   326   216   255    2.57    1.69    2.01
# 15               Indiana   108    92   127    1.60    1.36    1.87
# 16                  Iowa    52    39    49    1.65    1.22    1.53
# 17                Kansas    37    37    43    1.27    1.26    1.47
# 18              Kentucky    66    67    57    1.48    1.49    1.26
# 19             Louisiana    88    99    86    1.89    2.13    1.86
# 20                 Maine    18    17    14    1.34    1.25    1.02
# 21              Maryland   209   148   192    3.45    2.40    3.11
# 22         Massachusetts   178   142   151    2.58    2.02    2.16
# 23              Michigan   131   101   136    1.31    1.00    1.35
# 24             Minnesota   148   117   134    2.62    2.05    2.35
# 25           Mississippi    58    41    45    1.95    1.39    1.53
# 26              Missouri    70    79    77    1.14    1.28    1.25
# 27               Montana     2     4     3    0.19    0.37    0.27
# 28              Nebraska    17    33    22    0.88    1.68    1.12
# 29                Nevada    53    57    61    1.71    1.83    1.94
# 30         New Hampshire     6    12    12    0.44    0.87    0.86
# 31            New Jersey   310   245   279    3.49    2.64    3.01
# 32            New Mexico    41    29    24    1.95    1.37    1.13
# 33              New York   746   605   681    3.83    3.00    3.43
# 34        North Carolina   185   159   178    1.76    1.52    1.69
# 35          North Dakota    18    10    15    2.36    1.28    1.94
# 36                  Ohio   150   130   149    1.28    1.10    1.26
# 37              Oklahoma    73    67    69    1.84    1.69    1.73
# 38                Oregon    70    67    78    1.66    1.58    1.84
# 39          Pennsylvania   199   156   166    1.55    1.20    1.28
# 40          Rhode Island    14     7    17    1.32    0.64    1.55
# 41        South Carolina    80    67    88    1.55    1.31    1.70
# 42          South Dakota    16    16    12    1.80    1.80    1.34
# 43             Tennessee   129   113    85    1.89    1.63    1.22
# 44                 Texas  1154   883   991    3.98    3.02    3.36
# 45                  Utah    27    29    17    0.84    0.88    0.51
# 46               Vermont     4     3     2    0.64    0.47    0.31
# 47              Virginia   191   169   161    2.23    1.96    1.86
# 48            Washington   221   163   199    2.90    2.11    2.57
# 49         West Virginia     9    13     7    0.50    0.73    0.39
# 50             Wisconsin    51    35    66    0.88    0.59    1.12
# 51               Wyoming     1     0     3    0.17    0.00    0.52

# %% [markdown]
# - We need to differentiate "Number of TB cases" and "TB incidence"

# %%
# Renaming columns
rename_dict = {'2019': 'TB cases 2019',
               '2020': 'TB cases 2020',
               '2021': 'TB cases 2021',
               '2019.1': 'TB incidence 2019',
               '2020.1': 'TB incidence 2020',
               '2021.1': 'TB incidence 2021'}
tb_df = tb_df.rename(columns=rename_dict)
tb_df
# Out:
#        U.S. jurisdiction  TB cases 2019  TB cases 2020  TB cases 2021  \
# 0                  Total           8900           7173           7860
# 1                Alabama             87             72             92
# 2                 Alaska             58             58             58
# 3                Arizona            183            136            129
# 4               Arkansas             64             59             69
# 5             California           2111           1706           1750
# 6               Colorado             66             52             58
# 7            Connecticut             67             54             54
# 8               Delaware             18             17             43
# 9   District of Columbia             24             19             19
# 10               Florida            558            412            499
# 11               Georgia            302            221            228
# 12                Hawaii             99             92            106
# 13                 Idaho              7              8              4
# 14              Illinois            326            216            255
# 15               Indiana            108             92            127
# 16                  Iowa             52             39             49
# 17                Kansas             37             37             43
# 18              Kentucky             66             67             57
# 19             Louisiana             88             99             86
# 20                 Maine             18             17             14
# 21              Maryland            209            148            192
# 22         Massachusetts            178            142            151
# 23              Michigan            131            101            136
# 24             Minnesota            148            117            134
# 25           Mississippi             58             41             45
# 26              Missouri             70             79             77
# 27               Montana              2              4              3
# 28              Nebraska             17             33             22
# 29                Nevada             53             57             61
# 30         New Hampshire              6             12             12
# 31            New Jersey            310            245            279
# 32            New Mexico             41             29             24
# 33              New York            746            605            681
# 34        North Carolina            185            159            178
# 35          North Dakota             18             10             15
# 36                  Ohio            150            130            149
# 37              Oklahoma             73             67             69
# 38                Oregon             70             67             78
# 39          Pennsylvania            199            156            166
# 40          Rhode Island             14              7             17
# 41        South Carolina             80             67             88
# 42          South Dakota             16             16             12
# 43             Tennessee            129            113             85
# 44                 Texas           1154            883            991
# 45                  Utah             27             29             17
# 46               Vermont              4              3              2
# 47              Virginia            191            169            161
# 48            Washington            221            163            199
# 49         West Virginia              9             13              7
# 50             Wisconsin             51             35             66
# 51               Wyoming              1              0              3
#
#     TB incidence 2019  TB incidence 2020  TB incidence 2021
# 0                2.71               2.16               2.37
# 1                1.77               1.43               1.83
# 2                7.91               7.92               7.92
# 3                2.51               1.89               1.77
# 4                2.12               1.96               2.28
# 5                5.35               4.32               4.46
# 6                1.15               0.90               1.00
# 7                1.88               1.50               1.50
# 8                1.84               1.71               4.29
# 9                3.39               2.75               2.84
# 10               2.60               1.91               2.29
# 11               2.84               2.06               2.11
# 12               6.99               6.34               7.35
# 13               0.39               0.43               0.21
# 14               2.57               1.69               2.01
# 15               1.60               1.36               1.87
# 16               1.65               1.22               1.53
# 17               1.27               1.26               1.47
# 18               1.48               1.49               1.26
# 19               1.89               2.13               1.86
# 20               1.34               1.25               1.02
# 21               3.45               2.40               3.11
# 22               2.58               2.02               2.16
# 23               1.31               1.00               1.35
# 24               2.62               2.05               2.35
# 25               1.95               1.39               1.53
# 26               1.14               1.28               1.25
# 27               0.19               0.37               0.27
# 28               0.88               1.68               1.12
# 29               1.71               1.83               1.94
# 30               0.44               0.87               0.86
# 31               3.49               2.64               3.01
# 32               1.95               1.37               1.13
# 33               3.83               3.00               3.43
# 34               1.76               1.52               1.69
# 35               2.36               1.28               1.94
# 36               1.28               1.10               1.26
# 37               1.84               1.69               1.73
# 38               1.66               1.58               1.84
# 39               1.55               1.20               1.28
# 40               1.32               0.64               1.55
# 41               1.55               1.31               1.70
# 42               1.80               1.80               1.34
# 43               1.89               1.63               1.22
# 44               3.98               3.02               3.36
# 45               0.84               0.88               0.51
# 46               0.64               0.47               0.31
# 47               2.23               1.96               1.86
# 48               2.90               2.11               2.57
# 49               0.50               0.73               0.39
# 50               0.88               0.59               1.12
# 51               0.17               0.00               0.52

# %%
# row = 0 is total. We don't need it.
tb_df = tb_df.drop(0) # drop index 0
tb_df.head()
# Out:
#   U.S. jurisdiction  TB cases 2019  TB cases 2020  TB cases 2021  \
# 1           Alabama             87             72             92
# 2            Alaska             58             58             58
# 3           Arizona            183            136            129
# 4          Arkansas             64             59             69
# 5        California           2111           1706           1750
#
#    TB incidence 2019  TB incidence 2020  TB incidence 2021
# 1               1.77               1.43               1.83
# 2               7.91               7.92               7.92
# 3               2.51               1.89               1.77
# 4               2.12               1.96               2.28
# 5               5.35               4.32               4.46

# %%
tb_df.sum()
# Out:
# U.S. jurisdiction    AlabamaAlaskaArizonaArkansasCaliforniaColorado...
# TB cases 2019                                                     8900
# TB cases 2020                                                     7173
# TB cases 2021                                                     7860
# TB incidence 2019                                               107.23
# TB incidence 2020                                                90.93
# TB incidence 2021                                               100.57
# dtype: object

# %% [markdown]
# - The total TB cases look right.
# - The incidence numbers are not right.
# - We need more information to calculate it correctly. **We need population information.**

# %% [markdown]
# #### Population information from Census data
#
# - U.S. Census population estimates source ([2019](https://www.census.gov/data/tables/time-series/demo/popest/2010s-state-total.html)), source ([2020-2021](https://www.census.gov/data/tables/time-series/demo/popest/2020s-state-total.html)).
#
# - There are a few new methods here:
#
#   - `df.convert_dtypes()` ([documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.convert_dtypes.html)) conveniently converts all float dtypes into ints and is out of scope for the class.
#   - `df.drop_na()` ([documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html)) will be explained in more detail next time.

# %%
census_2010s_df = pd.read_csv("/content/nst-est2019-01.csv", header=3, thousands=",")
census_2010s_df
# Out:
#                                            Unnamed: 0       Census  \
# 0                                       United States  308745538.0
# 1                                           Northeast   55317240.0
# 2                                             Midwest   66927001.0
# 3                                               South  114555744.0
# 4                                                West   71945553.0
# ..                                                ...          ...
# 58  Note: The estimates are based on the 2010 Cens...          NaN
# 59                                Suggested Citation:          NaN
# 60  Table 1. Annual Estimates of the Resident Popu...          NaN
# 61    Source: U.S. Census Bureau, Population Division          NaN
# 62                        Release Date: December 2019          NaN
#
#     Estimates Base         2010         2011         2012         2013  \
# 0      308758105.0  309321666.0  311556874.0  313830990.0  315993715.0
# 1       55318443.0   55380134.0   55604223.0   55775216.0   55901806.0
# 2       66929725.0   66974416.0   67157800.0   67336743.0   67560379.0
# 3      114563030.0  114866680.0  116006522.0  117241208.0  118364400.0
# 4       71946907.0   72100436.0   72788329.0   73477823.0   74167130.0
# ..             ...          ...          ...          ...          ...
# 58             NaN          NaN          NaN          NaN          NaN
# 59             NaN          NaN          NaN          NaN          NaN
# 60             NaN          NaN          NaN          NaN          NaN
# 61             NaN          NaN          NaN          NaN          NaN
# 62             NaN          NaN          NaN          NaN          NaN
#
#            2014         2015         2016         2017         2018  \
# 0   318301008.0  320635163.0  322941311.0  324985539.0  326687501.0
# 1    56006011.0   56034684.0   56042330.0   56059240.0   56046620.0
# 2    67745167.0   67860583.0   67987540.0   68126781.0   68236628.0
# 3   119624037.0  120997341.0  122351760.0  123542189.0  124569433.0
# 4    74925793.0   75742555.0   76559681.0   77257329.0   77834820.0
# ..          ...          ...          ...          ...          ...
# 58          NaN          NaN          NaN          NaN          NaN
# 59          NaN          NaN          NaN          NaN          NaN
# 60          NaN          NaN          NaN          NaN          NaN
# 61          NaN          NaN          NaN          NaN          NaN
# 62          NaN          NaN          NaN          NaN          NaN
#
#            2019
# 0   328239523.0
# 1    55982803.0
# 2    68329004.0
# 3   125580448.0
# 4    78347268.0
# ..          ...
# 58          NaN
# 59          NaN
# 60          NaN
# 61          NaN
# 62          NaN
#
# [63 rows x 13 columns]

# %% [markdown]
# Do some basic data cleaning

# %%
census_2010s_df = (
    census_2010s_df
    .rename(columns={"Unnamed: 0": "Geographic Area"})
    .drop(columns=["Census", "Estimates Base"])
    .convert_dtypes() # "smart" converting of columns to int, use at your own risk
    .dropna()  # we'll introduce this very soon
)
census_2010s_df
# Out:
#           Geographic Area       2010       2011       2012       2013  \
# 0           United States  309321666  311556874  313830990  315993715
# 1               Northeast   55380134   55604223   55775216   55901806
# 2                 Midwest   66974416   67157800   67336743   67560379
# 3                   South  114866680  116006522  117241208  118364400
# 4                    West   72100436   72788329   73477823   74167130
# 5                .Alabama    4785437    4799069    4815588    4830081
# 6                 .Alaska     713910     722128     730443     737068
# 7                .Arizona    6407172    6472643    6554978    6632764
# 8               .Arkansas    2921964    2940667    2952164    2959400
# 9             .California   37319502   37638369   37948800   38260787
# 10              .Colorado    5047349    5121108    5192647    5269035
# 11           .Connecticut    3579114    3588283    3594547    3594841
# 12              .Delaware     899593     907381     915179     923576
# 13  .District of Columbia     605226     619800     634924     650581
# 14               .Florida   18845537   19053237   19297822   19545621
# 15               .Georgia    9711881    9802431    9901430    9972479
# 16                .Hawaii    1363963    1379329    1394804    1408243
# 17                 .Idaho    1570746    1583910    1595324    1611206
# 18              .Illinois   12840503   12867454   12882510   12895129
# 19               .Indiana    6490432    6516528    6537703    6568713
# 20                  .Iowa    3050745    3066336    3076190    3092997
# 15               Georgia   10732390   10790385   10913150   11029227
# 16                Hawaii    1451181    1446745    1439399    1435138
# 17                 Idaho    1849339    1904537    1938996    1964726
# 18              Illinois   12790357   12690341   12582515   12549689
# 19               Indiana    6789098    6813798    6832274    6862199
# 20                  Iowa    3190904    3197944    3199693    3207004
# 21                Kansas    2938124    2937946    2936716    2940546
# 22              Kentucky    4508155    4507600    4511563    4526154
# 23             Louisiana    4652022    4627047    4588023    4573749
# 24                 Maine    1364517    1378787    1389338    1395722
# 25              Maryland    6173689    6175045    6163981    6180253
# 26         Massachusetts    6997713    6991951    6982740    7001399
# 27              Michigan   10070627   10038117   10033281   10037261
# 28             Minnesota    5710578    5717968    5714300    5737915
# 29           Mississippi    2958409    2949582    2938928    2939690
# 30              Missouri    6154426    6170393    6177168    6196156
# 31               Montana    1087211    1106366    1122878    1132812
# 32              Nebraska    1963273    1964253    1968060    1978379
# 33                Nevada    3115840    3146632    3177421    3194176
# 34         New Hampshire    1378702    1387494    1399003    1402054
# 35            New Jersey    9272392    9269175    9260817    9290841
# 36            New Mexico    2118488    2116950    2113476    2114371
# 37              New York   20104710   19854526   19673200   19571216
# 38        North Carolina   10453812   10567100   10695965   10835491
# 39          North Dakota     779563     777982     778912     783926
# 40                  Ohio   11798292   11765227   11759697   11785935
# 41              Oklahoma    3965234    3991634    4019271    4053824
# 42                Oregon    4245044    4256465    4239379    4233358
# 43          Pennsylvania   12995477   13013614   12972091   12961683
# 44          Rhode Island    1096444    1097092    1093842    1095962
# 45        South Carolina    5132151    5193848    5282955    5373555
# 46          South Dakota     887852     896299     909869     919318
# 47             Tennessee    6926091    6963709    7048976    7126489
# 48                 Texas   29234361   29561286   30029848   30503301
# 49                  Utah    3283982    3339284    3381236    3417734
# 50               Vermont     642936     647093     647110     647464
# 51              Virginia    8637193    8657348    8679099    8715698
# 52            Washington    7724566    7741433    7784477    7812880
# 53         West Virginia    1791562    1785249    1774035    1770071
# 54             Wisconsin    5896700    5879978    5890543    5910955
# 55               Wyoming     577664     579548     581629     584057
# 57           Puerto Rico    3281557    3262693    3220113    3205691

# %% [markdown]
# #### Time to merge all three data
# - tb data, census2010s, census2020s
# - So that we have all population data from 2019-2021

# %%
# merge TB dataframe with two US census dataframes
tb_census_df = (
    tb_df
    .merge(right=census_2010s_df,
           left_on="U.S. jurisdiction", right_on="Geographic Area")
    .merge(right=census_2020s_df,
           left_on="U.S. jurisdiction", right_on="Geographic Area")
)
tb_census_df.tail()
# Out:
#    U.S. jurisdiction  TB cases 2019  TB cases 2020  TB cases 2021  \
# 46          Virginia            191            169            161
# 47        Washington            221            163            199
# 48     West Virginia              9             13              7
# 49         Wisconsin             51             35             66
# 50           Wyoming              1              0              3
#
#     TB incidence 2019  TB incidence 2020  TB incidence 2021 Geographic Area_x  \
# 46               2.23               1.96               1.86          Virginia
# 47               2.90               2.11               2.57        Washington
# 48               0.50               0.73               0.39     West Virginia
# 49               0.88               0.59               1.12         Wisconsin
# 50               0.17               0.00               0.52           Wyoming
#
#        2010     2011  ...     2015     2016     2017     2018     2019  \
# 46  8023699  8101155  ...  8361808  8410106  8463587  8501286  8535519
# 47  6742830  6826627  ...  7163657  7294771  7423362  7523869  7614893
# 48  1854239  1856301  ...  1842050  1831023  1817004  1804291  1792147
# 49  5690475  5705288  ...  5760940  5772628  5790186  5807406  5822434
# 50   564487   567299  ...   585613   584215   578931   577601   578759
#
#     Geographic Area_y     2020     2021     2022     2023
# 46           Virginia  8637193  8657348  8679099  8715698
# 47         Washington  7724566  7741433  7784477  7812880
# 48      West Virginia  1791562  1785249  1774035  1770071
# 49          Wisconsin  5896700  5879978  5890543  5910955
# 50            Wyoming   577664   579548   581629   584057
#
# [5 rows x 23 columns]

# %% [markdown]
# - We don't need all of these. Only 2019 - 2021

# %%
# try merging again, but cleaner this time
tb_census_df = (
    tb_df
    .merge(right=census_2010s_df[["Geographic Area", "2019"]],
           left_on="U.S. jurisdiction", right_on="Geographic Area")
    .drop(columns="Geographic Area")
    .merge(right=census_2020s_df[["Geographic Area", "2020", "2021"]],
           left_on="U.S. jurisdiction", right_on="Geographic Area")
    .drop(columns="Geographic Area")
)
tb_census_df.tail()
# Out:
#    U.S. jurisdiction  TB cases 2019  TB cases 2020  TB cases 2021  \
# 46          Virginia            191            169            161
# 47        Washington            221            163            199
# 48     West Virginia              9             13              7
# 49         Wisconsin             51             35             66
# 50           Wyoming              1              0              3
#
#     TB incidence 2019  TB incidence 2020  TB incidence 2021     2019     2020  \
# 46               2.23               1.96               1.86  8535519  8637193
# 47               2.90               2.11               2.57  7614893  7724566
# 48               0.50               0.73               0.39  1792147  1791562
# 49               0.88               0.59               1.12  5822434  5896700
# 50               0.17               0.00               0.52   578759   577664
#
#        2021
# 46  8657348
# 47  7741433
# 48  1785249
# 49  5879978
# 50   579548

# %% [markdown]
# #### Reproduce incidence
#
# Let's recompute incidence to make sure we know where the original CDC numbers came from.
#
# From the [CDC report](https://www.cdc.gov/mmwr/volumes/71/wr/mm7112a1.htm#T1_down): TB incidence is computed as “Cases per 100,000 persons using mid-year population estimates from the U.S. Census Bureau.”
#
# If we define a group as 100,000 people, then we can compute the TB incidence for a given state population as
#
# $\text{TB incidence} = \frac{\text{#TB cases in population}}{\text{population}} \times 100000$

# %%
# Let's try this for 2019:
tb_census_df["recompute incidence 2019"] = (
    tb_census_df["TB cases 2019"]/tb_census_df["2019"] * 100_000
)
tb_census_df.head()
# Out:
#   U.S. jurisdiction  TB cases 2019  TB cases 2020  TB cases 2021  \
# 0           Alabama             87             72             92
# 1            Alaska             58             58             58
# 2           Arizona            183            136            129
# 3          Arkansas             64             59             69
# 4        California           2111           1706           1750
#
#    TB incidence 2019  TB incidence 2020  TB incidence 2021      2019  \
# 0               1.77               1.43               1.83   4903185
# 1               7.91               7.92               7.92    731545
# 2               2.51               1.89               1.77   7278717
# 3               2.12               1.96               2.28   3017804
# 4               5.35               4.32               4.46  39512223
#
#        2020      2021  recompute incidence 2019
# 0   5031864   5050380                  1.774357
# 1    732964    734923                  7.928425
# 2   7186683   7272487                  2.514179
# 3   3014348   3028443                  2.120747
# 4  39503200  39145060                  5.342651

# %% [markdown]
# Let's use a for-loop and Python format strings to compute TB incidence for all years.

# %%
# recompute incidence for all years
for year in [2019, 2020, 2021]:
    tb_census_df[f"recompute incidence {year}"] = (
        round(tb_census_df[f"TB cases {year}"]/tb_census_df[f"{year}"]*100_000,2)
    )
tb_census_df
# Out:
#        U.S. jurisdiction  TB cases 2019  TB cases 2020  TB cases 2021  \
# 0                Alabama             87             72             92
# 1                 Alaska             58             58             58
# 2                Arizona            183            136            129
# 3               Arkansas             64             59             69
# 4             California           2111           1706           1750
# 5               Colorado             66             52             58
# 6            Connecticut             67             54             54
# 7               Delaware             18             17             43
# 8   District of Columbia             24             19             19
# 9                Florida            558            412            499
# 10               Georgia            302            221            228
# 11                Hawaii             99             92            106
# 12                 Idaho              7              8              4
# 13              Illinois            326            216            255
# 14               Indiana            108             92            127
# 15                  Iowa             52             39             49
# 16                Kansas             37             37             43
# 17              Kentucky             66             67             57
# 18             Louisiana             88             99             86
# 19                 Maine             18             17             14
# 20              Maryland            209            148            192
# 21         Massachusetts            178            142            151
# 22              Michigan            131            101            136
# 23             Minnesota            148            117            134
# 24           Mississippi             58             41             45
# 25              Missouri             70             79             77
# 26               Montana              2              4              3
# 27              Nebraska             17             33             22
# 28                Nevada             53             57             61
# 29         New Hampshire              6             12             12
# 30            New Jersey            310            245            279
# 31            New Mexico             41             29             24
# 32              New York            746            605            681
# 33        North Carolina            185            159            178
# 34          North Dakota             18             10             15
# 35                  Ohio            150            130            149
# 36              Oklahoma             73             67             69
# 37                Oregon             70             67             78
# 38          Pennsylvania            199            156            166
# 39          Rhode Island             14              7             17
# 40        South Carolina             80             67             88
# 41          South Dakota             16             16             12
# 42             Tennessee            129            113             85
# 43                 Texas           1154            883            991
# 44                  Utah             27             29             17
# 45               Vermont              4              3              2
# 46              Virginia            191            169            161
# 47            Washington            221            163            199
# 48         West Virginia              9             13              7
# 49             Wisconsin             51             35             66
# 50               Wyoming              1              0              3
#
#     TB incidence 2019  TB incidence 2020  TB incidence 2021      2019  \
# 0                1.77               1.43               1.83   4903185
# 1                7.91               7.92               7.92    731545
# 2                2.51               1.89               1.77   7278717
# 3                2.12               1.96               2.28   3017804
# 4                5.35               4.32               4.46  39512223
# 5                1.15               0.90               1.00   5758736
# 6                1.88               1.50               1.50   3565287
# 7                1.84               1.71               4.29    973764
# 8                3.39               2.75               2.84    705749
# 9                2.60               1.91               2.29  21477737
# 10               2.84               2.06               2.11  10617423
# 11               6.99               6.34               7.35   1415872
# 12               0.39               0.43               0.21   1787065
# 13               2.57               1.69               2.01  12671821
# 14               1.60               1.36               1.87   6732219
# 15               1.65               1.22               1.53   3155070
# 16               1.27               1.26               1.47   2913314
# 17               1.48               1.49               1.26   4467673
# 18               1.89               2.13               1.86   4648794
# 19               1.34               1.25               1.02   1344212
# 20               3.45               2.40               3.11   6045680
# 21               2.58               2.02               2.16   6892503
# 22               1.31               1.00               1.35   9986857
# 23               2.62               2.05               2.35   5639632
# 24               1.95               1.39               1.53   2976149
# 25               1.14               1.28               1.25   6137428
# 26               0.19               0.37               0.27   1068778
# 27               0.88               1.68               1.12   1934408
# 28               1.71               1.83               1.94   3080156
# 29               0.44               0.87               0.86   1359711
# 30               3.49               2.64               3.01   8882190
# 31               1.95               1.37               1.13   2096829
# 4                       4.47
# 5                        1.0
# 6                        1.5
# 7                       4.28
# 8                       2.84
# 9                       2.29
# 10                      2.11
# 11                      7.33
# 12                      0.21
# 13                      2.01
# 14                      1.86
# 15                      1.53
# 16                      1.46
# 17                      1.26
# 18                      1.86
# 19                      1.02
# 20                      3.11
# 21                      2.16
# 22                      1.35
# 23                      2.34
# 24                      1.53
# 25                      1.25
# 26                      0.27
# 27                      1.12
# 28                      1.94
# 29                      0.86
# 30                      3.01
# 31                      1.13
# 32                      3.43
# 33                      1.68
# 34                      1.93
# 35                      1.27
# 36                      1.73
# 37                      1.83
# 38                      1.28
# 39                      1.55
# 40                      1.69
# 41                      1.34
# 42                      1.22
# 43                      3.35
# 44                      0.51
# 45                      0.31
# 46                      1.86
# 47                      2.57
# 48                      0.39
# 49                      1.12
# 50                      0.52

# %% [markdown]
# ### Some words about Date and Time
# - Time stamp is another common data
# - Need to be careful about time and date formatting!!
# - US is MM/DD/YY. TH is DD/MM/YY. JP is YY/MM/DD.

# %% [markdown]
# # ---- Break -----

# %% [markdown]
# ## Dealing with Text

# %% [markdown]
# ## Why work with text? Two common goals
#
# 1. **Canonicalization**:  Convert data that has more than one possible presentation into a standard form.
#   - Ex: Join tables with mismatched labels
#
# <img src= 'https://drive.google.com/thumbnail?id=1qpza0rUz-MuzC9hQ4cafSXB8ujXzgGwe&sz=w1000' width = 750></img>

# %% [markdown]
# ## Why work with text? Two common goals
#
# 1. **Canonicalization**:  Convert data that has more than one possible presentation into a standard form.
#   - Ex: Join tables with mismatched labels
#
# 2. **Extract information** into a new feature (column)
#   - Ex: Extract data and times from log files
#
# <img src= 'https://drive.google.com/thumbnail?id=1JDfMlTbwPPGcEzadWHLjaIxi1XAo7sr8&sz=w1000' width = 600></img>

# %% [markdown]
# ### Python String Methods
#
# - Transformation: `s.lower()`, `s.upper()`
# - Split: `s.split(...)`
# - membership: `'ab' in s`
# - replacement: `s.replace(substring, newstring)`
# - substring: `s[1:4]`
# - length: `len(s)`
#
# **Problem**: Work on one string and not a list of string. Slow when you need to for loop in a large table.

# %% [markdown]
# ### Pandas String Methods
# - Pandas provides a method of **vectorizing** text operations: the `.str` operator
# - **Syntax**: `Series.str.<string_operation>()`
# - Apply the function `<string_operation>` to every string contained in the Series

# %%
# Load data for this section
states = pd.read_csv("/content/county_and_state.csv")
populations = pd.read_csv("/content/county_and_population.csv")

# display allows us to view a DataFrame without returning it as an object
display(states)
display(populations)
# Out:
#                        County State
# 0              De Witt County    IL
# 1        Lac qui Parle County    MN
# 2      Lewis and Clark County    MT
# 3  St John the Baptist Parish    LS
#                  County  Population
# 0                DeWitt       16798
# 1         Lac Qui Parle        8067
# 2         Lewis & Clark       55716
# 3  St. John the Baptist       43044

# %%
#Ex1 str.lower()
populations['County'].str.lower()
# Out:
# 0                  dewitt
# 1           lac qui parle
# 2           lewis & clark
# 3    st. john the baptist
# Name: County, dtype: object

# %%
#Ex2 str.replace()
populations['County'].str.replace('&','and')
# Out:
# 0                  DeWitt
# 1           Lac Qui Parle
# 2         Lewis and Clark
# 3    St. John the Baptist
# Name: County, dtype: object

# %% [markdown]
# ### `.str` Methods
#
#
# <img src= 'https://drive.google.com/thumbnail?id=12hXiKY3DgFqNjgtcq4T1SDqCO9CjiBRe&sz=w1000' width = 750></img>

# %% [markdown]
# #### Merging these two datasets
# - we need to **canonicalize** the "County" string data to apply a common formatting.

# %%
def canonicalize_county(county_series):
    return (county_series.str.lower()               # lowercase
            .str.replace(' ', '')                   # remove space
            .str.replace('&', 'and')                # replace &
            .str.replace('.', '')                   # remove dot
            .str.replace('county', '')              # remove "county"
            .str.replace('parish', '')              # remove "parish"
            )

display(canonicalize_county(states["County"]))
display(canonicalize_county(populations["County"]))
# Out:
# 0              dewitt
# 1         lacquiparle
# 2       lewisandclark
# 3    stjohnthebaptist
# Name: County, dtype: object
# 0              dewitt
# 1         lacquiparle
# 2       lewisandclark
# 3    stjohnthebaptist
# Name: County, dtype: object

# %%
states["Canonical County"] = canonicalize_county(states["County"])
populations["Canonical County"] = canonicalize_county(populations["County"])
display(states)
display(populations)
# Out:
#                        County State  Canonical County
# 0              De Witt County    IL            dewitt
# 1        Lac qui Parle County    MN       lacquiparle
# 2      Lewis and Clark County    MT     lewisandclark
# 3  St John the Baptist Parish    LS  stjohnthebaptist
#                  County  Population  Canonical County
# 0                DeWitt       16798            dewitt
# 1         Lac Qui Parle        8067       lacquiparle
# 2         Lewis & Clark       55716     lewisandclark
# 3  St. John the Baptist       43044  stjohnthebaptist

# %% [markdown]
# Now, the merge works as expected!

# %%
states.merge(populations, on="Canonical County")
# Out:
#                      County_x State  Canonical County              County_y  \
# 0              De Witt County    IL            dewitt                DeWitt
# 1        Lac qui Parle County    MN       lacquiparle         Lac Qui Parle
# 2      Lewis and Clark County    MT     lewisandclark         Lewis & Clark
# 3  St John the Baptist Parish    LS  stjohnthebaptist  St. John the Baptist
#
#    Population
# 0       16798
# 1        8067
# 2       55716
# 3       43044

# %% [markdown]
# ### Extracting Log Data
#
# <img src= 'https://drive.google.com/thumbnail?id=1JDfMlTbwPPGcEzadWHLjaIxi1XAo7sr8&sz=w1000' width = 600></img>

# %%
# Loading the log file
log_fname = '/content/log.txt'
with open(log_fname, 'r') as f:
    log_lines = f.readlines()
log_lines
# Out:
# ['169.237.46.168 - - [26/Jan/2014:10:47:58 -0800] "GET /stat141/Winter04/ HTTP/1.1" 200 2585 "http://anson.ucdavis.edu/courses/"\n',
#  '193.205.203.3 - - [2/Feb/2005:17:23:6 -0800] "GET /stat141/Notes/dim.html HTTP/1.0" 404 302 "http://eeyore.ucdavis.edu/stat141/Notes/session.html"\n',
#  '169.237.46.240 - "" [3/Feb/2006:10:18:37 -0800] "GET /stat141/homework/Solutions/hw1Sol.pdf HTTP/1.1"\n']

# %% [markdown]
# - We want to extract the day, month, year, hour, minutes, seconds, and timezone.
# - Let's start with the first line.

# %%
first = log_lines[0]
first
# Out:
# '169.237.46.168 - - [26/Jan/2014:10:47:58 -0800] "GET /stat141/Winter04/ HTTP/1.1" 200 2585 "http://anson.ucdavis.edu/courses/"\n'

# %% [markdown]
# - Get the data inside the square brackes by **splitting** string at the square brackets

# %%
pertinent = (
    first.split("[")[1] # remove everything before the first [
    .split(']')[0] # Remove everything after the second square ]
) # find the text enclosed in square brackets
pertinent
# Out:
# '26/Jan/2014:10:47:58 -0800'

# %% [markdown]
# - Next, split up date by `/`

# %%
day, month,rest  = pertinent.split('/')       # split up the date/month/year

print("Day:   ", day)
print("Month: ", month)
print("Rest:  ", rest)
# Out:
# Day:    26
# Month:  Jan
# Rest:   2014:10:47:58 -0800

# %% [markdown]
# - Next, split up the hour:minute:second

# %%
year, hour, minute, rest = rest.split(':')    # split up the hour:minute:second

print("Year:   ", year)
print("Hour:   ", hour)
print("Minute: ", minute)
print("Rest:   ", rest)
# Out:
# Year:    2014
# Hour:    10
# Minute:  47
# Rest:    58 -0800

# %% [markdown]
# - Lastly, split the timezone after the blank space

# %%
seconds, time_zone = rest.split(' ')          # split the timezone after the blank space
day, month, year, hour, minute, seconds, time_zone
# Out:
# ('26', 'Jan', '2014', '10', '47', '58', '-0800')

# %% [markdown]
# #### Now, we will do it with Pandas `.str`

# %%
logs = pd.read_csv("/content/log.txt", header=None)[0] #get Series! (Why?)

print("Original input!")
display(logs)
# Out:
# Original input!
# 0    169.237.46.168 - - [26/Jan/2014:10:47:58 -0800...
# 1    193.205.203.3 - - [2/Feb/2005:17:23:6 -0800] "...
# 2    169.237.46.240 - "" [3/Feb/2006:10:18:37 -0800...
# Name: 0, dtype: object

# %%
# Split [] and then /
df = (
    logs.str.split("[")
        .str[1]
        .str.split("]")
        .str[0]
        .str.split("/", expand=True)
        .rename(columns={0: "Day", 1: "Month", 2: "Rest"})
)
df
# Out:
#   Day Month                 Rest
# 0  26   Jan  2014:10:47:58 -0800
# 1   2   Feb   2005:17:23:6 -0800
# 2   3   Feb  2006:10:18:37 -0800

# %%
# split :
df = (
    df.join(df["Rest"].str.split(":", expand=True))
        .drop(columns=["Rest"])
        .rename(columns={0: "Year", 1: "Hour", 2: "Minute", 3: "Rest"})
)
df
# Out:
#   Day Month  Year Hour Minute      Rest
# 0  26   Jan  2014   10     47  58 -0800
# 1   2   Feb  2005   17     23   6 -0800
# 2   3   Feb  2006   10     18  37 -0800

# %%
# split space
df = (
    df.join(df["Rest"].str.split(" ", expand=True))
        .drop(columns=["Rest"])
        .rename(columns = {0: "Seconds", 1: "Timezone"})
)

# done
df
# Out:
#   Day Month  Year Hour Minute Seconds Timezone
# 0  26   Jan  2014   10     47      58    -0800
# 1   2   Feb  2005   17     23       6    -0800
# 2   3   Feb  2006   10     18      37    -0800

# %% [markdown]
# ## Regular Expressions
# - A **reg**ular **ex**pression (“regex”) is a sequence of characters that specifies a search pattern.
# - It is an embedded domain specific programming language (**a tiny programming language**)

# %% [markdown]
# ### String Extraction with Regex
#
# - Python `re.findall` returns a list of **all extracted matches**:

# %%
#Example
import re

text = "My phone number is 017-456-6789 bro, or actually maybe it’s 321-425-6789.";

pattern = r"[0-9]{3}-[0-9]{3}-[0-9]{4}"

re.findall(pattern, text)
# Out:
# ['017-456-6789', '321-425-6789']

# %% [markdown]
# ### Goals for Regex
#
# The goal of today is **NOT** to memorize the language of regular expressions!
# Instead:
# - Understand what regex is capable of.
# - Parse and create regex, **with a reference table**.

# %% [markdown]
# ### Learn from Practice
# - Use vocabulary (metacharacter, escape character, groups, etc.) to **describe regex** metacharacters.
# - **Differentiate** between `(), [], {}`
# - Design your own **character classes** with `\d, \w, \s, […-…], ^,` etc.
# - Use Python and pandas regex methods.

# %% [markdown]
# ### Resources for Practicing Regex
# - [regex101.com](regex101.com): provides a visually appealing and easy to use platform for experimenting with regular expressions.
#   - **Important**: choose the Python “flavor” in the left sidebar
#
# <img src= 'https://drive.google.com/thumbnail?id=1G9qRRnzueiMogfWDCI7zOIOE9ROsyr6l&sz=w1000' width = 800></img>

# %% [markdown]
# ### Regex Basics
# - There are four basic operations in regex

# %% [markdown]
# ##### Concentenation - "look for consecutive characters"
#
# - `AABAAB` matches `AABAAB`

# %% [markdown]
# #### | - “or”
# - `AA|BAAB` matches `AA` or `BAAB`

# %% [markdown]
# #### * - “zero or more”
# - `AB*A` matches `AA, ABA, ABBA, …`

# %% [markdown]
# #### ( ) - “consider a group”
# - `(AB)*A` matches `A, ABA, ABABA, …`
# - `A(A|B)AAB` matches `AAAAB` or `ABAAB`

# %% [markdown]
# - `*`, `( )`, and `|` are called **metacharacters** - they represent an operation, rather than a literal text character

# %% [markdown]
# ### Basic Regex
#
# <img src= 'https://drive.google.com/thumbnail?id=1P15x87nJG3iOtbvvXamsHg5S-SDTrQN4&sz=w1000' width = 800></img>

# %% [markdown]
# #### Ex1 (Slido)
#
# Which regex patterns will match the string "ABBA"? Select all that apply.

# %% [markdown]
# #### Ex2 (Slido)
#
# Which pattern matches moon, moooon, etc?
#
# Your expression should match any *even* number of “o”s except zero (i.e. don't match mn, mooon).

# %% [markdown]
# #### Try it yourself
#
# - https://regex101.com/r/8tkQ23/1
# - https://regex101.com/r/kJpHeZ/1

# %% [markdown]
# ### 6 More Regex Operations

# %% [markdown]
# #### `.` - “look for any character”
#
# - `.U.U.U.` matches `CUMULUS`, `JUGULUM`

# %% [markdown]
# #### `+` - “one or more”
#
# - `AB+` matches `AB, ABB, ABBB, …`

# %% [markdown]
# #### `?` - “zero or one” ("optional")
# - `AB?` matches `A, AB`

# %% [markdown]
# #### `{x}` - “repeat exactly x times”
# - `AB{2}` matches `ABB`

# %% [markdown]
# #### `{x, y}` - “repeat between x and y times”
# - `AB{0,2}` matches `A, AB, ABB`

# %% [markdown]
# #### `[ ]` - “define a character class”
# - `[A-Za-z]` matches `A, a, B, b…`
# - `[A-Z]` - any uppercase letter between `A` and `Z`
# - `[0-9]` (or `\d`) - any digit between `0` and `9`
# - `[A-Za-z0-9]` (or `\w`) - any letter, any digit
#
# Use ^ to negate a class = match any character other than what follows
# - `[^A-Z]` - anything that is *not* an uppercase letter between A and Z

# %% [markdown]
# ### Regex Expand
#
# <img src= 'https://drive.google.com/thumbnail?id=1Q_5IC03bfxXwlg1He5wIC9NBG4Dd1ZVu&sz=w1000' width = 800></img>

# %% [markdown]
# #### Ex3 (Slido)
#
# Choose a cleaner solution to the example from before! Which pattern matches moon, moooon, etc?

# %% [markdown]
# #### Ex4 (Slido)
#
# What pattern matches any lowercase alphabetic string that has a repeated vowel (noon, peel, festoon, loop, oodles, etc)?

# %% [markdown]
# ### Regex is greedy
#
# - Regex is **greedy** - it will look for the longest possible match in a string
#
# - Example: `<div>.*</div>`
# - Demo: https://regex101.com/r/HATiTH/1
#
# - In English:
#   - “Look for the exact string **\<div>**"
#   - then, “look for any character 0 or more times”
#   - then, “look for the exact string **\</div>**"
#
# - “This is a **\<div>**example\</div> of greediness \<div>in**\</div>** regular expressions.”
#
# - We can fix this by making the pattern **non-greedy**:
#   - `<div>.*?</div>`
#   - `?` makes the multipliers non-greedy.

# %% [markdown]
# ### More Regex Operations

# %% [markdown]
# #### `\` - 'read the next character literally'
# - `a\+b` mataches `a+b`

# %% [markdown]
# #### `^` - “match the beginning of a string”
# - `^abc` does not match `123 abc`

# %% [markdown]
# #### `$` - “match the end of a string”
# - `abc$` does not match `abc 123`

# %% [markdown]
# ### Extra Regex Expand
#
# <img src= 'https://drive.google.com/thumbnail?id=1iVhxSRjF1T8xXFO5W598jLVMJt0TSAzD&sz=w1000' width = 800></img>

# %% [markdown]
# ### Regex Functions

# %% [markdown]
# #### Before We Begin: Raw Strings in Python
# - When specifying a pattern, we strongly suggest using raw strings.
# - A raw string is created by prepending `r` to the string delimiters
#   - `(r"...", r'...', r"""...""", r'''...''')`
# - Don't need to escape special characters with `\`
#   - e.g. `"\\\\section"` = `r"\\section"`

# %% [markdown]
# ### Extraction: `re.findall(pattern, text)`
# - `re.findall(pattern, text)`: Return a list of all matches to `pattern`.
# - `ser.str.findall(pattern)`: Return a Series of lists.

# %%
# ex: findall
text = "My phone number is 017-456-6789 bro, or actually maybe it’s 321-425-6789.";

pattern = r"[0-9]{3}-[0-9]{3}-[0-9]{4}"

re.findall(pattern, text)
# Out:
# ['017-456-6789', '321-425-6789']

# %%
# ex: .str.findall
df_phones = pd.DataFrame(
    ['987-653-4321',
     'forty',
     '123-453-6789 bro or 321-451-6789',
     '999-999-9999'],
    columns=['Phone'])
df_phones
# Out:
#                               Phone
# 0                      987-653-4321
# 1                             forty
# 2  123-453-6789 bro or 321-451-6789
# 3                      999-999-9999

# %%
df_phones['Phone'].str.findall(pattern)
# Out:
# 0                  [987-653-4321]
# 1                              []
# 2    [123-453-6789, 321-451-6789]
# 3                  [999-999-9999]
# Name: Phone, dtype: object

# %% [markdown]
# ### Extraction with Capture Groups
# - Earlier we used parentheses to specify the **order of operations**.
# - Parenthesis can have another meaning:
#   - When using certain regex functions, ( ) specifies a capture group.
#   - Extract only the portion of the regex pattern inside the capture group

# %%
text = """I will meet you at 08:30:00 pm tomorrow"""
pattern = ".*(\d\d):(\d\d):(\d\d).*"
matches = re.findall(pattern, text)
matches
# Out:
# [('08', '30', '00')]

# %% [markdown]
# ### Extraction with Capture Groups
# - `ser.str.extract(pattern)`: Returns a DataFrame of each capture group's **first** match in the string
# - `ser.str.extractall(pattern)`: Returns a multi-indexed DataFrame of **all** matches for each capture group

# %%
# Will extract the first match of all groups
pattern_group_mult = r"([0-9]{3})-([0-9]{3})-([0-9]{4})" # 3 groups
df_phones['Phone'].str.extract(pattern_group_mult)
# Out:
#      0    1     2
# 0  987  653  4321
# 1  NaN  NaN   NaN
# 2  123  453  6789
# 3  999  999  9999

# %%
# -> DataFrame, one row per match
df_phones['Phone'].str.extractall(pattern_group_mult)
# Out:
#            0    1     2
#   match
# 0 0      987  653  4321
# 2 0      123  453  6789
#   1      321  451  6789
# 3 0      999  999  9999

# %% [markdown]
# #### Substitution
# - `re.sub(pattern, repl, text)`: Returns text with all instances of `pattern` replaced by `repl`.

# %%
# In regular Python, canonicalize with re.sub (standing for "substitute"):
text = '<div><td valign="top">Moo</td></div>'
pattern = r"<[^>]+>"
re.sub(pattern, '', text)
# Out:
# 'Moo'

# %% [markdown]
# How it works:
# - `pattern` matches HTML tags
# - Then, sub/replace HTML tags with `repl=''` (i.e., empty string)

# %% [markdown]
# - `ser.str.replace(pattern, repl, regex=True )`: Returns Series with all instances of `pattern` in Series `ser` replaced by `repl`.

# %%
# example dataframe of strings
df_html = pd.DataFrame(['<div><td valign="top">Moo</td></div>',
                   '<a href="http://ds100.org">Link</a>',
                   '<b>Bold text</b>'], columns=['Html'])
df_html
# Out:
#                                    Html
# 0  <div><td valign="top">Moo</td></div>
# 1   <a href="http://ds100.org">Link</a>
# 2                      <b>Bold text</b>

# %%
# Series -> Series
df_html["Html"].str.replace(pattern, '', regex=True).to_frame()
# Out:
#         Html
# 0        Moo
# 1       Link
# 2  Bold text

# %% [markdown]
# ### Revisiting Text Log Processing using Regex

# %%
line = log_lines[0]
display(line)

# (numbers)/(Words)/(Numbers):(numbers):(numbers):(numbers):(numbes) (any)
pattern = r'\[(\d+)\/(\w+)\/(\d+):(\d+):(\d+):(\d+) (.+)\]'

day, month, year, hour, minute, second, time_zone = re.findall(pattern, line)[0] # get first match
day, month, year, hour, minute, second, time_zone
# Out:
# '169.237.46.168 - - [26/Jan/2014:10:47:58 -0800] "GET /stat141/Winter04/ HTTP/1.1" 200 2585 "http://anson.ucdavis.edu/courses/"\n'
# ('26', 'Jan', '2014', '10', '47', '58', '-0800')

# %%
df = pd.DataFrame(log_lines, columns=['Log'])
df
# Out:
#                                                  Log
# 0  169.237.46.168 - - [26/Jan/2014:10:47:58 -0800...
# 1  193.205.203.3 - - [2/Feb/2005:17:23:6 -0800] "...
# 2  169.237.46.240 - "" [3/Feb/2006:10:18:37 -0800...

# %%
pattern = r'\[(\d+)\/(\w+)\/(\d+):(\d+):(\d+):(\d+) (.+)\]'
df['Log'].str.extractall(pattern)
# Out:
#           0    1     2   3   4   5      6
#   match
# 0 0      26  Jan  2014  10  47  58  -0800
# 1 0       2  Feb  2005  17  23   6  -0800
# 2 0       3  Feb  2006  10  18  37  -0800

# %% [markdown]
# ### Pandas Summary
#
#
# <img src= 'https://drive.google.com/thumbnail?id=1Vi4EoCKG5IoUAurQ0ihkOWmt4Stag-PM&sz=w1000' width = 800></img>

# %% [markdown]
# ### Limitations of Regular Expressions
# - Need to know the syntax well
# - Hard to read and debug
# - Reality: Just ask AI...

# %% [markdown]
# <a href="https://colab.research.google.com/github/yongsa-nut/TU_CN240_DataScience_671/blob/main/Pandas_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lecture 2: Panda Basic
#
# Materials are from https://ds100.org/sp24/ and https://r4ds.hadley.nz/

# %% [markdown]
# ## Bookkeeping
#
# - Sildo
# - project
# - Data is just a bunch of number - no good or bad.
# - Schedule
# - Homework

# %% [markdown]
# ## the Data Science Lifecylce
#
# ![function_flowchart.png](https://drive.google.com/uc?export=view&id=1D9FGsFlFPkqVLgK63zAOTxhcpJjTrUvn)

# %% [markdown]
# ## Zoaming the programing part
#
# ![function_flowchart.png](https://drive.google.com/uc?export=view&id=1I3zCww9xAlaI56J4slvUq8BsvHN-6t0w)

# %% [markdown]
# ## This Lecture Overview
#
# - Anatomy of data in Pandas
# - Data Attributes
# - Indexing and Slicing
# - Conditional Selection
# - Adding, Removing, and Modifying Column
# - Useful utility functions
# - groupby() (If we have time)

# %% [markdown]
# ## Today's Setup
# - We are given **nice and clean (tidy) data**.
# - Or, we build them from scratch.
# - Our data will be in a table = **Tabular Data**

# %% [markdown]
# ## Tidy Tabular Data
# - Row = one observation (e.g., a person, an animal, a country)
# - Column = one feature or variable of that observation (e.g., age, height)
# - Each value is a cell; each cell is a single value.
#
# ![function_flowchart.png](https://drive.google.com/uc?export=view&id=1tCVJbFIOjDDjqZ5M0DyXru74dlGRLZZq)

# %% [markdown]
# ## Data Science coding vs. Normal coding
# - More interactive.
# - Run one or a few lines of code at a time.
# - Be able to read document. There are too many functions to cover.

# %% [markdown]
# ## Pandas library
# - The Python Data Analysis Library
# - Can import, extract, modify, combine data
# - Pandas stands for Panel Data
# ![function_flowchart.png](https://drive.google.com/uc?export=view&id=1LVLFOeqLRlsiphFkvmQai2w606SmEJdW)

# %%
# import pandas (colab has pandas pre installed)
import pandas as pd       # pd is the common alias for pandas

# %% [markdown]
# ## Tabular Data in Pandas
# - A table data = a **Dataframe**
# - A column = a **Series**
# - Dataframe = a collections of Series

# %% [markdown]
# ## Series
# - A `Series` is a 1-dimensional array-like object. It contains:
#   - Values of the **same type**.
#   - Data labels, called the index.

# %%
# To create a Series we can pass a list into Series method
s = pd.Series(["Hello","World","!"])
s
# Out:
# 0    Hello
# 1    World
# 2        !
# dtype: object

# %%
s.values
# Out:
# array(['Hello', 'World', '!'], dtype=object)

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %% [markdown]
# In the example above, `pandas` automatically generated an `Index` of integer labels.
#
# We can also create a `Series` object by providing a custom `Index`.

# %%
s = pd.Series([-1, 10, 2], index = ["a", "b", "c"])
s
# Out:
# a    -1
# b    10
# c     2
# dtype: int64

# %%
s.values
# Out:
# array([-1, 10,  2])

# %%
s.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %% [markdown]
# After it has been created, we can reassign the Index of a Series to a new Index.

# %%
s.index = ["first", "second", "third"]
s
# Out:
# first     -1
# second    10
# third      2
# dtype: int64

# %% [markdown]
# ## Selection in Series
#
# We can select a single value or a set of values in a `Series` using:
#
# - A single label
# - A list of labels
# - A filtering condition

# %% [markdown]
# ### Selection using one or more label(s)

# %%
# Selection using a single label
# Notice how the return value is a single array element
s = pd.Series([4, -2, 0, 6], index = ["a", "b", "c", "d"])
s["a"]
# Out:
# 4

# %%
# Selection using a list of labels
# Notice how the return value is another Series
s = pd.Series([4, -2, 0, 6], index = ["a", "b", "c", "d"])
s[["a", "d"]]

# %% [markdown]
# ### Selection using a filter condition
#
# - Indexing using a boolean series/list
# - Only select index with `True`

# %%
# Filter condition: select all elements greater than 0
s = pd.Series([4, -2, 0, 6], index = ["a", "b", "c", "d"])
s>0
# Out:
# a     True
# b    False
# c    False
# d     True
# dtype: bool

# %%
# Use the Boolean filter to select data from the original Series
s[s>0]
# Out:
# a    4
# c    0
# dtype: int64

# %% [markdown]
# **Ex**: What is the output of the following code?

# %%
example = pd.Series([4,5,6], index = ['one','two','three'])
example[example > 4].values

# %% [markdown]
# ## DataFrame
#
# A `DataFrame` is a 2-D tabular data structure with both row and column labels.
#
# In this lecture, we will see how a `DataFrame` can be created from scratch or loaded from a file.

# %% [markdown]
# ## Creating a new `DataFrame` object
#
# - From a CSV file
# - Using a list and column names
# - From a dictionary
# - From a `Series`

# %% [markdown]
# ### Creating a DataFrame from a CSV file
#
# - For loading data into a `DataFrame`, pandas has a number of very useful file reading tools.
# - We'll be using `read_csv` today to load data from a CSV file into a `DataFrame` object.
# - On colab you need to upload (right click) the data to the colab disk first.
#
# ![function_flowchart.png](https://drive.google.com/uc?export=view&id=1IFlqQmEYH117LKsLcioLQv1cLoHIz2s_)

# %% [markdown]
# ## Penguin dataset
#
# - Source: https://github.com/allisonhorst/palmerpenguins
# - Download: https://github.com/mcnakhaee/palmerpenguins/blob/master/palmerpenguins/data/penguins.csv
#
# ![image.png](https://imgur.com/orZWHly.png)
# source: @allison_horst https://github.com/allisonhorst/penguins

# %%
# Data from https://github.com/mcnakhaee/palmerpenguins
penguins = pd.read_csv("/content/penguins.csv")
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# ### Creating a DataFrame using a list and column names

# %%
# Creating a single-column DataFrame using a list
df_list_1 = pd.DataFrame([1, 2, 3],
                         columns = ["Number"])
df_list_1
# Out:
#    Number
# 0       1
# 1       2
# 2       3

# %%
# Creating a multi-column DataFrame using a list of lists
df_list_2 = pd.DataFrame([[1, "one"], [2, "two"]],
                         columns = ["Number", "Description"])
df_list_2
# Out:
#    Number Description
# 0       1         one
# 1       2         two

# %% [markdown]
# ### Creating a DataFrame from a dictionary

# %%
# Creating a DataFrame from a dictionary of columns
df_dict_1 = pd.DataFrame({"Fruit":["Strawberry", "Orange"],
                          "Price":[5.49, 3.99]})
df_dict_1
# Out:
#         Fruit  Price
# 0  Strawberry   5.49
# 1      Orange   3.99

# %%
# Creating a DataFrame from a list of row dictionaries
df_dict_2 = pd.DataFrame([{"Fruit":"Strawberry", "Price":5.49},
                          {"Fruit":"Orange", "Price":3.99}])
df_dict_2
# Out:
#         Fruit  Price
# 0  Strawberry   5.49
# 1      Orange   3.99

# %% [markdown]
# ### Creating a DataFrame from a Series

# %%
# In the examples below, we create a DataFrame from a Series

s_a = pd.Series(["a1", "a2", "a3"], index = ["r1", "r2", "r3"])
s_b = pd.Series(["b1", "b2", "b3"], index = ["r1", "r2", "r3"])

# Passing Series objects for columns
df_ser = pd.DataFrame({"A-column":s_a, "B-column":s_b})
df_ser
# Out:
#    A-column B-column
# r1       a1       b1
# r2       a2       b2
# r3       a3       b3

# %%
# Passing a Series to the DataFrame constructor to make a one-column dataframe
df_ser = pd.DataFrame(s_a)
df_ser
# Out:
#      0
# r1  a1
# r2  a2
# r3  a3

# %% [markdown]
# **Ex**: What is the output of the following code?

# %%
df = pd.DataFrame({'c1':[1,2,3,4], 'c2':[2,4,6,8]})
df.columns

# %% [markdown]
# ## Useful DataFrame Attributes
# - `DataFrame.index` -> get all indexes
# - `DataFrame.columns` -> get all columns
# - `DataFrame.shape` -> get the shape (dimension) of the DataFrame
# - More here https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html

# %%
# Data from https://github.com/mcnakhaee/palmerpenguins
penguins = pd.read_csv("/content/penguins.csv")            # copy from above
penguins

# %%
penguins.index
# Out:
# RangeIndex(start=0, stop=344, step=1)

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %%
penguins.shape  # (row, column)
# Out:
# (344, 8)

# %% [markdown]
# ## Data Extraction

# %% [markdown]
# ### `.head` and `.tail`
# - `df.head(n)` - return the first $n$ rows of the DataFrame df (default n = 5)
# - `df.tail(n)` - return the last $n$ rows of the DataFrame df (default n = 5)

# %%
penguins = pd.read_csv("/content/penguins.csv")            # copy from above
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
penguins.head(7)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007
# 5       3650.0    male  2007
# 6       3625.0  female  2007

# %%
penguins.tail()
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009

# %% [markdown]
# ### Label-Based Extraction Using `loc`
#
# - **Syntax**: `df.loc[row_labels, col_labels]`
# - Arguments to .loc can be:
#   - A list.
#   - A slice (syntax is inclusive of the right-hand side of the slice).
#   - A single value.

# %%
penguins.columns #let's check the column names again
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %%
# Selection by a list
penguins.loc[[17, 23, 31], ['species','island','sex','year']]
# Out:
#    species     island   sex  year
# 17  Adelie  Torgersen  male  2007
# 23  Adelie     Biscoe  male  2007
# 31  Adelie      Dream  male  2007

# %%
# Selection by a list and a slice of columns
penguins.loc[[17, 23, 31], "island":"body_mass_g"]
# Out:
#        island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 17  Torgersen            42.5           20.7              197.0       4500.0
# 23     Biscoe            38.2           18.1              185.0       3950.0
# 31      Dream            37.2           18.1              178.0       3900.0

# %%
# Extracting all rows using a colon
penguins.loc[:, ['species','island','sex','year']]
# Out:
#        species     island     sex  year
# 0       Adelie  Torgersen    male  2007
# 1       Adelie  Torgersen  female  2007
# 2       Adelie  Torgersen  female  2007
# 3       Adelie  Torgersen     NaN  2007
# 4       Adelie  Torgersen  female  2007
# ..         ...        ...     ...   ...
# 339  Chinstrap      Dream    male  2009
# 340  Chinstrap      Dream  female  2009
# 341  Chinstrap      Dream    male  2009
# 342  Chinstrap      Dream    male  2009
# 343  Chinstrap      Dream  female  2009
#
# [344 rows x 4 columns]

# %%
# Extracting all columns using a colon
penguins.loc[[17, 23, 31], :]
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 17  Adelie  Torgersen            42.5           20.7              197.0
# 23  Adelie     Biscoe            38.2           18.1              185.0
# 31  Adelie      Dream            37.2           18.1              178.0
#
#     body_mass_g   sex  year
# 17       4500.0  male  2007
# 23       3950.0  male  2007
# 31       3900.0  male  2007

# %%
# Selection by a list and a single-column label -> Series
penguins.loc[[17, 23, 31], 'sex']
# Out:
# 17    male
# 23    male
# 31    male
# Name: sex, dtype: object

# %%
# Note that if we pass "sex" in a list, the output will be a DataFrame
penguins.loc[[17, 23, 31], ['sex']]
# Out:
#      sex
# 17  male
# 23  male
# 31  male

# %%
# Selection by a row label and a column label -> a value
penguins.loc[1,'year']
# Out:
# 2007

# %% [markdown]
# **Ex**: what will the following code print out?

# %%
fruits = pd.DataFrame({"Fruit":["Strawberry", "Orange","Apple"],
                          "Price":[5.49, 3.99, 1.31],
                          "Size":[0.1,2,2.5]})
fruits.loc[[1],['Fruit','Size']]

# %% [markdown]
# ### Integer-based Extraction: iloc
#
# - `iloc` selects items by row and column **integer position**.
# - **Syntax**: `df.iloc[row_labels, col_labels]`
# - Arguments to `.iloc` can be:
#   - A list.
#   - A slice (syntax is inclusive of the right-hand side of the slice).
#   - A single value.

# %%
# Select the rows at positions 1, 2, and 3.
# Select the columns at positions 0, 1, and 2.
# Remember that Python indexing begins at position 0!
penguins.iloc[[1,2,3], [0,1,2]]
# Out:
#   species     island  bill_length_mm
# 1  Adelie  Torgersen            39.5
# 2  Adelie  Torgersen            40.3
# 3  Adelie  Torgersen             NaN

# %%
# Index-based extraction using a list of rows and a slice of column indices
penguins.iloc[[1,2,3], 0:3]
# Out:
#   species     island  bill_length_mm
# 1  Adelie  Torgersen            39.5
# 2  Adelie  Torgersen            40.3
# 3  Adelie  Torgersen             NaN

# %%
penguins.iloc[[1, 2, 3], 1]
# Out:
# 1    Torgersen
# 2    Torgersen
# 3    Torgersen
# Name: island, dtype: object

# %%
penguins.iloc[0, 1]
# Out:
# 'Torgersen'

# %% [markdown]
# **Ex**: what will the following code print out?

# %%
fruits = pd.DataFrame({"Fruit":["Strawberry", "Orange","Apple"],
                          "Price":[5.49, 3.99, 1.31],
                          "Size":[0.1,2,2.5]})
fruits.iloc[1:3,[2]]

# %% [markdown]
# ### Context-dependent Extraction using `[]`
#
# - We could technically do anything we want using `loc` or `iloc`.
# - However, in practice, the `[]` operator is often used instead to yield more concise code.
# - `[]` is a bit trickier to understand than `loc` or `iloc`, but it achieves essentially the same functionality. The difference is that `[]` is context-dependent.
# - `[]` only takes one argument, which may be:
#   - A slice of row integers.
#   - A list of column labels.
#   - A single column label.

# %% [markdown]
# #### If we provide a slice of row numbers, we get the numbered rows.

# %%
penguins[3:7]
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
#
#    body_mass_g     sex  year
# 3          NaN     NaN  2007
# 4       3450.0  female  2007
# 5       3650.0    male  2007
# 6       3625.0  female  2007

# %% [markdown]
# #### If we provide a list of column names, we get the listed columns.

# %%
penguins[['year','sex','species']]
# Out:
#      year     sex    species
# 0    2007    male     Adelie
# 1    2007  female     Adelie
# 2    2007  female     Adelie
# 3    2007     NaN     Adelie
# 4    2007  female     Adelie
# ..    ...     ...        ...
# 339  2009    male  Chinstrap
# 340  2009  female  Chinstrap
# 341  2009    male  Chinstrap
# 342  2009    male  Chinstrap
# 343  2009  female  Chinstrap
#
# [344 rows x 3 columns]

# %% [markdown]
# #### And if we provide a single column name we get back just that column, stored as a Series.

# %%
penguins['year']
# Out:
# 0      2007
# 1      2007
# 2      2007
# 3      2007
# 4      2007
#        ...
# 339    2009
# 340    2009
# 341    2009
# 342    2009
# 343    2009
# Name: year, Length: 344, dtype: int64

# %% [markdown]
# **Ex**: what will the following code print out?

# %%
fruits = pd.DataFrame({"Fruit":["Strawberry", "Orange","Apple"],
                          "Price":[5.49, 3.99, 1.31],
                          "Size":[0.1,2,2.5]})
fruits[1:3]

# %% [markdown]
# **Ex**: what will the following code print out?

# %%
weird = pd.DataFrame({
    1:["topdog","botdog"],
    "1":["topcat","botcat"]
})
weird

# %%
weird[1]

# %%
weird["1"]

# %%
weird[1:]

# %% [markdown]
# # ---- Break here ----

# %% [markdown]
# ## Dataset: California baby names
# - For the rest of today's lecture, we will work with `babynames` dataset,  which contains information about the names of infants born in California.
# - Website: https://www.ssa.gov/oact/babynames/limits.html
# - You can check the readme to learn more about the data

# %%
# Data from: https://www.ssa.gov/oact/babynames/state/namesbystate.zip
column_names = ['State', 'Sex', 'Year', 'Name', 'Count']
babynames = pd.read_csv('/content/CA.TXT', names = column_names)
babynames.head()
# Out:
#   State Sex  Year      Name  Count
# 0    CA   F  1910      Mary    295
# 1    CA   F  1910     Helen    239
# 2    CA   F  1910   Dorothy    220
# 3    CA   F  1910  Margaret    163
# 4    CA   F  1910   Frances    134

# %%
babynames.shape
# Out:
# (413894, 5)

# %% [markdown]
# ## Conditional Selection
# - `.loc` and `[ ]`  also accept boolean sequences as input.
# - Rows corresponding to True are extracted; rows corresponding to False are not.

# %%
babynames_first_10_rows = babynames.loc[:9, :]

babynames_first_10_rows
# Out:
#   State Sex  Year       Name  Count
# 0    CA   F  1910       Mary    295
# 1    CA   F  1910      Helen    239
# 2    CA   F  1910    Dorothy    220
# 3    CA   F  1910   Margaret    163
# 4    CA   F  1910    Frances    134
# 5    CA   F  1910       Ruth    128
# 6    CA   F  1910     Evelyn    126
# 7    CA   F  1910      Alice    118
# 8    CA   F  1910   Virginia    101
# 9    CA   F  1910  Elizabeth     93

# %% [markdown]
# By passing in a sequence (list, array, or Series) of boolean values, we can extract a subset of the rows in a DataFrame. We will keep only the rows that correspond to a boolean value of True.

# %%
# Notice how we have exactly 10 elements in our boolean array argument.
babynames_first_10_rows[[True, False, True, False, True, False, True, False, True, False]]
# Out:
#   State Sex  Year      Name  Count
# 0    CA   F  1910      Mary    295
# 2    CA   F  1910   Dorothy    220
# 4    CA   F  1910   Frances    134
# 6    CA   F  1910    Evelyn    126
# 8    CA   F  1910  Virginia    101

# %%
# Or using .loc to filter a DataFrame by a Boolean array argument.
babynames_first_10_rows.loc[[True, False, True, False, True, False, True, False, True, False], :]
# Out:
#   State Sex  Year      Name  Count
# 0    CA   F  1910      Mary    295
# 2    CA   F  1910   Dorothy    220
# 4    CA   F  1910   Frances    134
# 6    CA   F  1910    Evelyn    126
# 8    CA   F  1910  Virginia    101

# %% [markdown]
# ### Using boolean selction to check for entries
# Oftentimes, we'll use boolean selection to check for entries in a DataFrame that meet a particular condition.

# %%
# First, use a logical condition to generate a boolean Series
logical_operator = (babynames["Sex"] == "F")
logical_operator
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 413889    False
# 413890    False
# 413891    False
# 413892    False
# 413893    False
# Name: Sex, Length: 413894, dtype: bool

# %%
# Then, use this boolean Series to filter the DataFrame
babynames[logical_operator]
# Out:
#        State Sex  Year      Name  Count
# 0         CA   F  1910      Mary    295
# 1         CA   F  1910     Helen    239
# 2         CA   F  1910   Dorothy    220
# 3         CA   F  1910  Margaret    163
# 4         CA   F  1910   Frances    134
# ...      ...  ..   ...       ...    ...
# 243185    CA   F  2023  Zeppelin      5
# 243186    CA   F  2023   Zhamira      5
# 243187    CA   F  2023      Zina      5
# 243188    CA   F  2023     Zooey      5
# 243189    CA   F  2023     Zosia      5
#
# [243190 rows x 5 columns]

# %%
# Notice that we did not have to specify columns to select
# If no columns are referenced, pandas will automatically select all columns
babynames.loc[babynames["Sex"] == "F"]
# Out:
#        State Sex  Year      Name  Count
# 0         CA   F  1910      Mary    295
# 1         CA   F  1910     Helen    239
# 2         CA   F  1910   Dorothy    220
# 3         CA   F  1910  Margaret    163
# 4         CA   F  1910   Frances    134
# ...      ...  ..   ...       ...    ...
# 243185    CA   F  2023  Zeppelin      5
# 243186    CA   F  2023   Zhamira      5
# 243187    CA   F  2023      Zina      5
# 243188    CA   F  2023     Zooey      5
# 243189    CA   F  2023     Zosia      5
#
# [243190 rows x 5 columns]

# %% [markdown]
# ## Bitwise Operators
#
# - To filter on multiple conditions, we combine boolean operators using bitwise comparisons.
#
#
# | Symbol | Usage | Meaning |
# | ------ | ----- | ------  |
# | `~`    | `~p`   | not p   |
# | `\|`   | `p\|q` | p OR q  |
# | `&`    | `p&q`  | p AND q |
# | `^`    | `p^q`  | p XOR q |

# %%
# Selecting female  AND born before 2000
babynames[(babynames["Sex"] == "F") & (babynames["Year"] < 2000)]
# Out:
#        State Sex  Year      Name  Count
# 0         CA   F  1910      Mary    295
# 1         CA   F  1910     Helen    239
# 2         CA   F  1910   Dorothy    220
# 3         CA   F  1910  Margaret    163
# 4         CA   F  1910   Frances    134
# ...      ...  ..   ...       ...    ...
# 149057    CA   F  1999    Zareen      5
# 149058    CA   F  1999    Zeinab      5
# 149059    CA   F  1999     Zhane      5
# 149060    CA   F  1999      Zoha      5
# 149061    CA   F  1999     Zoila      5
#
# [149062 rows x 5 columns]

# %%
# Selecting female OR born before 2000
babynames[(babynames["Sex"] == "F") | (babynames["Year"] < 2000)]
# Out:
#        State Sex  Year      Name  Count
# 0         CA   F  1910      Mary    295
# 1         CA   F  1910     Helen    239
# 2         CA   F  1910   Dorothy    220
# 3         CA   F  1910  Margaret    163
# 4         CA   F  1910   Frances    134
# ...      ...  ..   ...       ...    ...
# 346088    CA   M  1999     Yuuki      5
# 346089    CA   M  1999  Zakariya      5
# 346090    CA   M  1999    Zavier      5
# 346091    CA   M  1999      Zayn      5
# 346092    CA   M  1999     Zayne      5
#
# [346093 rows x 5 columns]

# %% [markdown]
# **Ex**: We want to obtain the first three baby names with count > 250.

# %%
babynames[babynames['Count'] > 250].head(3)
# Out:
#     State Sex  Year  Name  Count
# 0      CA   F  1910  Mary    295
# 233    CA   F  1911  Mary    390
# 484    CA   F  1912  Mary    534

# %% [markdown]
# #### Selecting only a few names

# %%
# Note: The parentheses surrounding the code make it possible to break the code into multiple lines for readability
(
babynames[(babynames["Name"] == "Bella") |
          (babynames["Name"] == "Alex") |
          (babynames["Name"] == "Narges") |
          (babynames["Name"] == "Lisa")]
)
# Out:
#        State Sex  Year   Name  Count
# 6289      CA   F  1923  Bella      5
# 7512      CA   F  1925  Bella      8
# 12368     CA   F  1932   Lisa      5
# 14741     CA   F  1936   Lisa      8
# 17084     CA   F  1939   Lisa      5
# ...      ...  ..   ...    ...    ...
# 399773    CA   M  2019   Alex    438
# 402648    CA   M  2020   Alex    379
# 405452    CA   M  2021   Alex    334
# 408335    CA   M  2022   Alex    345
# 411228    CA   M  2023   Alex    329
#
# [321 rows x 5 columns]

# %%
# List comprehension. Not recommended. Use pandas methods instead. (faster in general)
names = ["Bella", "Alex", "Narges", "Lisa"]
new_list = [x in names for x in babynames["Name"]]
babynames[new_list]
# Out:
#        State Sex  Year   Name  Count
# 6289      CA   F  1923  Bella      5
# 7512      CA   F  1925  Bella      8
# 12368     CA   F  1932   Lisa      5
# 14741     CA   F  1936   Lisa      8
# 17084     CA   F  1939   Lisa      5
# ...      ...  ..   ...    ...    ...
# 399773    CA   M  2019   Alex    438
# 402648    CA   M  2020   Alex    379
# 405452    CA   M  2021   Alex    334
# 408335    CA   M  2022   Alex    345
# 411228    CA   M  2023   Alex    329
#
# [321 rows x 5 columns]

# %% [markdown]
# ### Alternatives to Direct Boolean Array Selection
#
# $\texttt{pandas}$ provides **many** alternatives, for example:
# - `.isin`
# - `.str.startswith`
# - `.groupby.filter` (later)

# %%
# A more concise method to achieve the above: .isin
names = ["Bella", "Alex", "Narges", "Lisa"]
display(babynames["Name"].isin(names))
display(babynames[babynames["Name"].isin(names)])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 413889    False
# 413890    False
# 413891    False
# 413892    False
# 413893    False
# Name: Name, Length: 413894, dtype: bool
#        State Sex  Year   Name  Count
# 6289      CA   F  1923  Bella      5
# 7512      CA   F  1925  Bella      8
# 12368     CA   F  1932   Lisa      5
# 14741     CA   F  1936   Lisa      8
# 17084     CA   F  1939   Lisa      5
# ...      ...  ..   ...    ...    ...
# 399773    CA   M  2019   Alex    438
# 402648    CA   M  2020   Alex    379
# 405452    CA   M  2021   Alex    334
# 408335    CA   M  2022   Alex    345
# 411228    CA   M  2023   Alex    329
#
# [321 rows x 5 columns]

# %%
# What if we only want names that start with "N"?
babynames[babynames["Name"].str.startswith("N")]
# Out:
#        State Sex  Year    Name  Count
# 76        CA   F  1910   Norma     23
# 83        CA   F  1910  Nellie     20
# 127       CA   F  1910    Nina     11
# 198       CA   F  1910    Nora      6
# 310       CA   F  1911  Nellie     23
# ...      ...  ..   ...     ...    ...
# 413795    CA   M  2023   Nilan      5
# 413796    CA   M  2023   Niles      5
# 413797    CA   M  2023    Nilo      5
# 413798    CA   M  2023     Nio      5
# 413799    CA   M  2023   Novah      5
#
# [12460 rows x 5 columns]

# %% [markdown]
# ## Adding, Removing, and Modifying Columns

# %% [markdown]
# ### Syntax for Adding a column
#
# 1. Use `[ ]` to reference the desired new column.
# 2. Assign this column to a Series or array of the appropriate length.

# %%
# Create a Series of the length of each name
babyname_lengths = babynames["Name"].str.len()

# Add a column named "name_lengths" that includes the length of each name
babynames["name_lengths"] = babyname_lengths

babynames
# Out:
#        State Sex  Year      Name  Count  name_lengths
# 0         CA   F  1910      Mary    295             4
# 1         CA   F  1910     Helen    239             5
# 2         CA   F  1910   Dorothy    220             7
# 3         CA   F  1910  Margaret    163             8
# 4         CA   F  1910   Frances    134             7
# ...      ...  ..   ...       ...    ...           ...
# 413889    CA   M  2023      Ziah      5             4
# 413890    CA   M  2023    Ziaire      5             6
# 413891    CA   M  2023    Zidane      5             6
# 413892    CA   M  2023      Zyan      5             4
# 413893    CA   M  2023      Zyir      5             4
#
# [413894 rows x 6 columns]

# %% [markdown]
# ### Syntax for modifying a column
#
# 1. Use [ ] to reference the existing column.
# 2. Assign this column to a new Series or array of the appropriate length.

# %%
# Modify the "name_lengths" column to be one less than its original value
babynames["name_lengths"] = babynames["name_lengths"] - 1
babynames
# Out:
#        State Sex  Year      Name  Count  name_lengths
# 0         CA   F  1910      Mary    295             3
# 1         CA   F  1910     Helen    239             4
# 2         CA   F  1910   Dorothy    220             6
# 3         CA   F  1910  Margaret    163             7
# 4         CA   F  1910   Frances    134             6
# ...      ...  ..   ...       ...    ...           ...
# 413889    CA   M  2023      Ziah      5             3
# 413890    CA   M  2023    Ziaire      5             5
# 413891    CA   M  2023    Zidane      5             5
# 413892    CA   M  2023      Zyan      5             3
# 413893    CA   M  2023      Zyir      5             3
#
# [413894 rows x 6 columns]

# %% [markdown]
# ### Renaming a column
#
# - `.rename()` takes in a **dictionary** that maps old column names to their new ones.

# %%
# Rename "name_lengths" to "Length"
babynames = babynames.rename(columns={"name_lengths":"Length"})
babynames
# Out:
#        State Sex  Year      Name  Count  Length
# 0         CA   F  1910      Mary    295       3
# 1         CA   F  1910     Helen    239       4
# 2         CA   F  1910   Dorothy    220       6
# 3         CA   F  1910  Margaret    163       7
# 4         CA   F  1910   Frances    134       6
# ...      ...  ..   ...       ...    ...     ...
# 413889    CA   M  2023      Ziah      5       3
# 413890    CA   M  2023    Ziaire      5       5
# 413891    CA   M  2023    Zidane      5       5
# 413892    CA   M  2023      Zyan      5       3
# 413893    CA   M  2023      Zyir      5       3
#
# [413894 rows x 6 columns]

# %% [markdown]
# ### Dropping a Column (or Row)
#
# - Remove columns using the `.drop` method.
# - The `.drop()` method assumes you're dropping a row by default.
# - Use `axis = "columns"` to drop a column instead.

# %%
# Remove our new "Length" column
babynames = babynames.drop("Length", axis="columns")
babynames
# Out:
#        State Sex  Year      Name  Count
# 0         CA   F  1910      Mary    295
# 1         CA   F  1910     Helen    239
# 2         CA   F  1910   Dorothy    220
# 3         CA   F  1910  Margaret    163
# 4         CA   F  1910   Frances    134
# ...      ...  ..   ...       ...    ...
# 413889    CA   M  2023      Ziah      5
# 413890    CA   M  2023    Ziaire      5
# 413891    CA   M  2023    Zidane      5
# 413892    CA   M  2023      Zyan      5
# 413893    CA   M  2023      Zyir      5
#
# [413894 rows x 5 columns]

# %% [markdown]
# ## An Important Note: DataFrame Copies
#
# - By default, $\texttt{pandas}$ methods create a **copy** of the `DataFrame`, without changing the original `DataFrame` at all.
# - To apply our changes, we must update our `DataFrame` to this new, modified copy.

# %% [markdown]
# ## Useful Built-in $\texttt{Pandas}$ Method

# %% [markdown]
# - `.shape` returns the shape of a DataFrame or Series in the form (number of rows, number of columns

# %%
# Returns the shape of the object in the format (num_rows, num_columns)
babynames.shape
# Out:
# (413894, 5)

# %% [markdown]
# - `.size` returns the total number of entries in a DataFrame or Series (number of rows times number of columns)

# %%
# Returns the total number of entries in the object, equal to num_rows * num_columns
babynames.size
# Out:
# 2069470

# %% [markdown]
# - `.describe()` returns a "description" of a DataFrame or Series that lists summary statistics of the data

# %%
# What summary statistics can we describe?
babynames.describe()
# Out:
#                 Year          Count
# count  413894.000000  413894.000000
# mean     1986.314353      79.140348
# std        27.190404     292.028292
# min      1910.000000       5.000000
# 25%      1969.000000       7.000000
# 50%      1992.000000      13.000000
# 75%      2008.000000      38.000000
# max      2023.000000    8263.000000

# %% [markdown]
# - The `Series.value_counts` method counts the number of occurrences of each unique value in a Series (it counts the number of times each value appears).

# %%
# Count the number of times each unique value occurs in a Series
babynames["Name"].value_counts()
# Out:
# Name
# Jean         225
# Francis      223
# Jessie       219
# Guadalupe    219
# Marion       215
#             ...
# Damaso         1
# Kanwal         1
# Karrina        1
# Kazzandra      1
# Vallen         1
# Name: count, Length: 20629, dtype: int64

# %% [markdown]
# - The `Series.unique` method returns an array of every unique value in a Series.

# %%
# Return an array of all unique values in the Series
babynames["Name"].unique()
# Out:
# array(['Mary', 'Helen', 'Dorothy', ..., 'Shohei', 'Shylo', 'Vallen'],
#       dtype=object)

# %% [markdown]
# - `.sort_values()`
# - `Series.sort_values( )` will automatically sort all values in the Series.
# - `DataFrame.sort_values(column_name)` **must specify** the name of the **column** to be used for sorting.

# %%
# Sort a Series
babynames["Name"].sort_values()
# Out:
# 387660      Aadan
# 369654      Aadan
# 372774      Aadan
# 401876    Aadarsh
# 388799      Aaden
#            ...
# 232190      Zyrah
# 220708      Zyrah
# 217445      Zyrah
# 197542      Zyrah
# 408216      Zyrus
# Name: Name, Length: 413894, dtype: object

# %%
# Sort a DataFrame – there are lots of Michaels in California
babynames.sort_values(by="Count", ascending=False)   # By default, rows are sorted in ascending order.
# Out:
#        State Sex  Year           Name  Count
# 271693    CA   M  1957        Michael   8263
# 270669    CA   M  1956        Michael   8257
# 321036    CA   M  1990        Michael   8247
# 285500    CA   M  1969        Michael   8244
# 286795    CA   M  1970        Michael   8197
# ...      ...  ..   ...            ...    ...
# 294982    CA   M  1975  Michaelangelo      5
# 294981    CA   M  1975          Micha      5
# 294980    CA   M  1975         Markus      5
# 294979    CA   M  1975   Marcoantonio      5
# 413893    CA   M  2023           Zyir      5
#
# [413894 rows x 5 columns]

# %% [markdown]
# ## Grouping
#
# **Our goal**:
# - **Group** together **rows** that fall under the **same category**.
#   - For example, group together all rows from the same year.
# - **Perform** an operation that **aggregates** across all rows in the category.
#   - For example, sum up the total number of babies born in that year.
#
# Grouping is a powerful tool to 1) perform large operations, all at once and 2) summarize trends in a dataset.

# %% [markdown]
# ## `groupby()`
#
# - A `.groupby()` operation involves some combination of **splitting the object, applying a function, and combining the results**.
#  - Calling `.groupby()` generates `DataFrameGroupBy` objects → "mini" sub-DataFrames
#  - Each subframe contains all rows that correspond to the same group (here, a particular year)
#
# ![function_flowchart.png](https://drive.google.com/uc?export=view&id=17SWiKIcJwIs_fCdluhz-8YZRSG0V3JvY)

# %% [markdown]
# ## `.groupby().agg()`
#
# - We cannot work directly with `DataFrameGroupBy` objects!
# - Instead, we transform a `DataFrameGroupBy` object back into a `DataFrame` using `.agg`
#   - `.agg` is how we apply an aggregation operation to the data.
#
# ![function_flowchart.png](https://drive.google.com/uc?export=view&id=1zWgXA5chJFOCXSToqgezsrbSE6Z9X7u_)

# %% [markdown]
# ## Full Syntax
#
# - `dataframe.groupby(column_name).agg(aggregation_function)`
# - Useful aggregation functions:
#   - `"sum",'size', "count", "max", "min", "mean", "first", "last"`
# - Complete list of agg: https://pandas.pydata.org/pandas-docs/stable/reference/groupby.html#computations-descriptive-stats

# %%
babynames.groupby("Year")

# %%
babynames[["Year", "Count"]].groupby("Year").agg("sum")
# Out:
#        Count
# Year
# 1910    9163
# 1911    9983
# 1912   17946
# 1913   22094
# 1914   26926
# ...      ...
# 2019  387325
# 2020  363307
# 2021  363206
# 2022  361960
# 2023  342550
#
# [114 rows x 1 columns]

# %% [markdown]
# ## Concluding `groupby.agg`
#
# A groupby operation involves some combination of **splitting the object, applying a function, and combining the results**.
#
# So far, we've seen that ```df.groupby("Year").agg(sum)```:
# - **Split** df into `sub-DataFrames` based on Year.
# - **Apply** the **sum** function to each column of each `sub-DataFrame`.
# - **Combine** the results of **sum** into a single `DataFrame`, indexed by Year.
#
# ![function_flowchart.png](https://drive.google.com/uc?export=view&id=1VAVHFB9K58y-Gz4JTFKRcX1RQV685DSk)

# %% [markdown]
# ## groupby exercise
#
# Q: What will go in the ??
#
# ![function_flowchart.png](https://drive.google.com/uc?export=view&id=1GgsQonNnm6mvopJUsjMOdaKZY43i-RFT)

# %% [markdown]
# ## Panda CheatSheat
# - https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf
